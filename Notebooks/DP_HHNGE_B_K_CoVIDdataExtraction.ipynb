# %%
import os, sys, importlib, subprocess, copy, zipfile
import rasterio, geohash

import geopandas as gpd
import pandas as pd
import numpy as np

from shapely.geometry import Point, box
from shapely.wkt import loads
from rasterio import features
from collections import Counter

sys.path.append("../")

import infrasap.vulnerability_mapping as vulmap
import infrasap.covid_data_extraction as cov
import infrasap.rasterMisc as rMisc
import infrasap.misc as misc
import infrasap.osmMisc as osm
import infrasap.UrbanRaster as urban

# %%
# define the input datasets
global_bounds = "/home/public/Data/GLOBAL/ADMIN/Admin0_Polys.shp"
global_adm1 = "/home/public/Data/GLOBAL/ADMIN/Admin1_Polys.shp"
global_adm2 = "/home/public/Data/GLOBAL/ADMIN/Admin2_Polys.shp"
pop_folder = "/home/public/Data/GLOBAL/Population/WorldPop_PPP_2020/GLOBAL_1km_Demographics"
output_folder = "/home/wb411133/data/Projects/CoVID"
population_raster = "/home/public/Data/GLOBAL/Population/WorldPop_PPP_2020/ppp_2020_1km_Aggregated.tif" 
lcRaster = "/home/public/Data/GLOBAL/LANDCOVER/GLOBCOVER/2015/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2015-v2.0.7.tif"
dhs_folder = '/home/public/Data/PROJECTS/CoVID/DHS'
dhs_files = {}
for root, dirs, files in os.walk(dhs_folder):
    for f in files:
        if f[-4:] == ".shp":
            dhs_files[f.replace(".shp", "")] = gpd.read_file(os.path.join(os.path.join(root, f)))


# Read in the global datasets
pop_files = os.listdir(pop_folder)
inG  = gpd.read_file(global_bounds)
inG1 = gpd.read_file(global_adm1)
inG2 = gpd.read_file(global_adm2)
inR = rasterio.open(population_raster)
inL = rasterio.open(lcRaster)

# %%
iso3 = "IDN"

# %%
# extract national bounds
country_folder = os.path.join(output_folder, iso3)
adm0_file = os.path.join(country_folder, "adm0.shp")
adm1_file = os.path.join(country_folder, "adm1.shp")
adm2_file = os.path.join(country_folder, "adm2.shp")
lc_file = os.path.join(country_folder, "LC.tif")

if not os.path.exists(country_folder):
    os.makedirs(country_folder)
country_bounds = inG.loc[inG['ISO3'] == iso3].to_crs({'init':'epsg:4326'})
country_adm1 = inG1.loc[inG1['ISO3'] == iso3].to_crs({'init':'epsg:4326'})
country_adm2 = inG2.loc[inG2['ISO3'] == iso3].to_crs({'init':'epsg:4326'})
if not os.path.exists(adm0_file):
    country_bounds.to_file(adm0_file)
if not os.path.exists(adm1_file):
    country_adm1.to_file(adm1_file)
if not os.path.exists(adm2_file):
    country_adm2.to_file(adm2_file)
if not os.path.exists(lc_file):
    rMisc.clipRaster(inL, gpd.read_file(adm0_file), lc_file)

country_bounds = country_bounds.to_crs({'init':'epsg:4326'})

# %%
cov.calculate_vulnerability(iso3, country_folder, country_bounds, pop_folder, pop_files)
misc.tPrint("***Calculated Vulnerability")

# %%
cov.create_urban_data(iso3, country_folder, country_bounds, inR, calc_urban=False)
misc.tPrint("***Calculated Urban Extents")                           
'''
except:
    misc.tPrint("%s errored on HD clusters" % iso3)
    try:
        create_urban_data(iso3, country_folder, country_bounds, inR, calc_urban=True, calc_hd_urban=False)
    except:
        misc.tPrint("%s errored on all clusters" % iso3)        
#extract_osm(country_bounds, country_folder)

misc.tPrint("***Extracted OSM")
'''

# %%
country_shape = country_bounds.unary_union

# %%
def combine_dhs_pop(popRaster, dhs_raster, out_file, factor=100):
    ''' 
    INPUT
        popRaster [rasterio]
        dhs_raster [rasterio]
        out_file [string]
        [optional] factor [int] - number to divide dhs_raster (converts percentage to fraction)
    '''
    inP = popRaster.read()
    dhs = dhs_raster.read()
    if factor != 1:
        dhs = dhs / factor
    dhs_pop = inP * (dhs)
    
    with rasterio.open(out_file, 'w', **popRaster.meta) as outR:
        outR.write(dhs_pop)

        
template = os.path.join(country_folder, "WP_2020_1km.tif")                
inP = rasterio.open(template)
# Process DHS data

# get a list of unique columns in the DHS data
total_columns = 0
try:
    del(all_columns)
except:
    pass
# get a list of all unique columns
for key, inD in dhs_files.items():
    cur_columns = list(inD.columns.values)
    try:
        all_columns = all_columns + cur_columns
    except:
        all_columns = cur_columns

col_count = Counter(all_columns)
unq_columns = [key for key, value in col_count.items() if value == 1]

# %%
cur_rasters = copy.deepcopy(cov.hnp_categories)

# %%
dhs_rasters = {}
for key, inD in dhs_files.items():
    sel_dhs = inD.loc[inD['ISO3'] == iso3]
    if sel_dhs.shape[0] > 0:
        for field in inD.columns:
            if field in unq_columns:
                out_file = os.path.join(country_folder, f'{key}_{field}.tif')
                out_file_pop = os.path.join(country_folder, f'{key}_{field}_pop.tif')
                try:
                    # rasteize the desired field in the inputDHS data                
                    if not os.path.exists(out_file) and not os.path.exists(out_file_pop):
                        rMisc.rasterizeDataFrame(inD, out_file, idField=field, templateRaster = template)

                    #Multiply the rasterized data frame by the population layer
                    if not os.path.exists(out_file_pop):
                        combine_dhs_pop(inP, rasterio.open(out_file), out_file_pop, factor=100)
                    if os.path.exists(out_file):
                        os.remove(out_file)
                    misc.tPrint(f'{key}: {field}')
                    dhs_rasters[f'{key}_{field}'] = {
                        'raster_file': f'{key}_{field}_pop.tif',
                        'vars': ['SUM', 'MEAN'],
                        'description': f'{key}_{field}'
                    }
                except:
                    misc.tPrint(f"Error processing {key} - {field}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-240d5363b1a7> in <module>
#       4     if sel_dhs.shape[0] > 0:
#       5         for field in inD.columns:
# ----> 6             if field in unq_columns:
#       7                 out_file = os.path.join(country_folder, f'{key}_{field}.tif')
#       8                 out_file_pop = os.path.join(country_folder, f'{key}_{field}_pop.tif')
#
# NameError: name 'unq_columns' is not defined

# %%
#Run zonal stats
cur_rasters = copy.deepcopy(cov.hnp_categories)
for key, values in cur_rasters.items():
    values['raster_file'] = os.path.join(country_folder, values['raster_file'])
    cur_rasters[key] = values
    
#Run zonal stats
dhs_final = copy.deepcopy(dhs_rasters)
for key, values in dhs_rasters.items():
    values['raster_file'] = os.path.join(country_folder, values['raster_file'])
    dhs_final[key] = values

all_shps = []
for root, dirs, files, in os.walk(country_folder):
    for f in files:
        if f[-4:] == ".shp" and not "zonal" in f:
            all_shps.append(os.path.join(root, f))

# %%
importlib.reload(cov)
cov.run_zonal(all_shps, cur_rasters, out_suffix="_BASE")

# %%
cov.run_zonal(all_shps, dhs_rasters, out_suffix="_DHS")

# %% [markdown]
# # DEBUGGING BELOW

# %%
# Merge urban fishnets at the national level
base_folder = "/home/wb411133/data/Projects/CoVID"
in_countries = os.listdir(base_folder)
all_fishnets = []
for iso3 in in_countries:
    cur_folder = os.path.join(base_folder, iso3, "FINAL_GEOMS")
    bad_fishnet = os.path.join(cur_folder, "COMBO_HD_URBAN_fishnet.geojson")
    if os.path.exists(bad_fishnet):
        os.remove(bad_fishnet)
    out_fishnet = os.path.join(cur_folder, "%s_COMBO_HD_URBAN_fishnet.geojson" % iso3)
    all_fishnets.append(out_fishnet)
    print(iso3)
    if not os.path.exists(out_fishnet):
        fishnets = []
        for root, dirs, files in os.walk(cur_folder):
            for f in files:
                if f[:3] == "HD_":
                    fishnets.append(os.path.join(root, f))
        try:
            del final
        except:
            pass
        if len(fishnets) > 0:
            for f in fishnets:
                curD = gpd.read_file(f)
                try:
                    final = final.append(curD)
                except:
                    final = curD
            final.to_file(out_fishnet, driver="GeoJSON")
# Out:
# VNM
# ARG
# PAK
# ZAF
# COL
# ZWE
# MNG
# SLE
# CPV
# KEN
# GHA
# AFG
# YEM
# ECU
# PRY
# MRT
# MDV
# KGZ
# HTI
# DJI
# KHM
# TJK
# GMB
# LKA
# SEN
# STP
# SLV
# VEN
# MLI
# RWA
# BOL
# TZA
# MAR
# IND
# IDN
# SDN
# AGO
# BEN
# BWA
# BFA
# BDI
# CMR
# CAF
# TCD
# COM
# COG
# CIV
# COD
# SSD
# ERI
# ETH
# GAB
# GNB
# GIN
# LSO
# LBR
# MDG
# MWI
# MUS
# MOZ
# NAM
# NER
# NGA
# SYC
# SOM
# SWZ
# TGO
# UGA
# ZMB
# LCA
# PHL
# GTM
# BGD
# BRA
# MEX
# EGY
# UKR
# PER
# LAO
# PSE
# NPL
# PNG
# DZA
# BLR
# BTN
# BIH
# NIC
# FJI
# GEO
# HND
# JOR
# MHL
# MDA
# MMR
# MKD
# PAN
# WSM
# SLB
# TUN
# TUR
# URY
# UZB
# ALB
# HRV
# IRN
# SRB
# TTO
# ATG
# CHN
# IRQ

# %%
# Zip all fishnets together
out_zip = "/home/wb411133/temp/HNP_Fishnets.zip"
with zipfile.ZipFile(out_zip, 'w', zipfile.ZIP_DEFLATED) as zf:
    for f in all_fishnets:
        if os.path.exists(f):
            zf.write(f, arcname=os.path.basename(f))

# %%
all_fishnets
# Out:
# ['/home/wb411133/data/Projects/CoVID/VNM/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ARG/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/PAK/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ZAF/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/COL/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ZWE/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MNG/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SLE/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/CPV/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/KEN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/GHA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/AFG/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/YEM/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ECU/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/PRY/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MRT/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MDV/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/KGZ/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/HTI/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/DJI/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/KHM/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/TJK/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/GMB/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/LKA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SEN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/STP/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SLV/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/VEN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MLI/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/RWA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BOL/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/TZA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MAR/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/IND/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/IDN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SDN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/AGO/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BEN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BWA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BFA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BDI/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/CMR/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/CAF/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/TCD/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/COM/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/COG/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/CIV/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/COD/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SSD/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ERI/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ETH/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/GAB/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/GNB/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/GIN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/LSO/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/LBR/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MDG/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MWI/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MUS/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MOZ/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/NAM/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/NER/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/NGA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SYC/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SOM/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SWZ/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/TGO/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/UGA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ZMB/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/LCA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/PHL/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/GTM/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BGD/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BRA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MEX/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/EGY/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/UKR/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/PER/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/LAO/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/PSE/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/NPL/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/PNG/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/DZA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BLR/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BTN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/BIH/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/NIC/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/FJI/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/GEO/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/HND/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/JOR/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MHL/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MDA/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MMR/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/MKD/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/PAN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/WSM/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SLB/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/TUN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/TUR/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/URY/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/UZB/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ALB/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/HRV/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/IRN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/SRB/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/TTO/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/ATG/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/CHN/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson',
#  '/home/wb411133/data/Projects/CoVID/IRQ/FINAL_GEOMS/COMBO_HD_URBAN_fishnet.geojson']

# %%
final.shape
# Out:
# (7015, 3)

# %% [markdown]
# # Join Mobility Results

# %%
in_shp  = "/home/wb411133/data/Projects/CoVID/IDN/FINAL_GEOMS/IDN_COMBO_HD_URBAN_fishnet.geojson"
out_shp = "/home/wb411133/data/Projects/CoVID/IDN/FINAL_GEOMS/IDN_COMBO_HD_URBAN_fishnet_20200101.shp"
in_mobility = "/home/wb411133/data/Projects/CoVID/IDN/FINAL_GEOMS/part-00000-tid-5083628924017813989-ab511d05-022c-4ed9-be33-6f51d59fc4b5-10404-1-c000.csv"

inS = gpd.read_file(in_shp)
inS.drop(['FID'], axis=1, inplace=True)
inS.set_index('geohash', inplace=True)
inM = pd.read_csv(in_mobility)
inM.set_index('geohash', inplace=True)
xx = inS.join(inM)

# %%
xx.to_file(out_shp)
