# %% [markdown]
# ### This notebook has various explorations of the market access tools, but is not desgined as a complete workflow. Use at your own discretion

# %%
import sys, os, importlib
import rasterio

import numpy as np
import pandas as pd
import geopandas as gpd
import osmnx as ox
import GOSTnets as gn
import skimage.graph as graph

from rasterio.mask import mask
from rasterio import features
from shapely.geometry import box, Point, Polygon
from scipy.ndimage import generic_filter
from pandana.loaders import osm

sys.path.append("../")

import infrasap.market_access as ma
import infrasap.rasterMisc as rMisc
from infrasap.misc import tPrint
#import infrasap.rai_calculator as rai

# %%
global_friction_surface = "/home/public/Data/GLOBAL/INFRA/FRICTION_2015/2015_friction_surface_v1.geotiff"

inG = rasterio.open(global_friction_surface)

# %%
global_admin = "/home/public/Data/GLOBAL/ADMIN/Admin0_Polys.shp"
inD = gpd.read_file(global_admin)
selD = inD.loc[inD['Region'] == "Sub-Saharan Africa"]
selD = selD.to_crs(inG.crs)
# Out:
#    OBJECTID ISO_A2  WB_ADM0_CO             WB_ADM0_NA    Shape_Leng  \
# 0         1     AF           1            Afghanistan  7.132529e+06
# 1         2     AL           3                Albania  1.743971e+06
# 2         3     DZ           4                Algeria  8.933841e+06
# 3         4     AS           5  American Samoa (U.S.)  1.744573e+05
# 4         5     SD           6                  Sudan  8.852111e+06
#
#      Shape_Area ISO3  UN_m49                      Region              incomeG  \
# 0  6.418379e+05  AFG       4                  South Asia           Low income
# 1  2.868177e+04  ALB       8       Europe & Central Asia  Upper middle income
# 2  2.309321e+06  DZA      12  Middle East & North Africa  Upper middle income
# 3  2.110162e+02  ASM      16         East Asia & Pacific  Upper middle income
# 4  1.844887e+06  SDN     736          Sub-Saharan Africa  Lower middle income
#
#   lendingC  FID_100                                           geometry
# 0      IDA        0  POLYGON ((7903635.422200002 4647361.696500003,...
# 1     IBRD      100  (POLYGON ((2145902.261799999 4941064.025700003...
# 2     IBRD      200  (POLYGON ((-125251.4530000016 4264455.85010000...
# 3     None      300  (POLYGON ((-18985804.4762 -1607929.979800001, ...
# 4      IDA      400  (POLYGON ((4282246.283599999 2048756.8814, 428...

# %%
# clip out the Africa Raster
out_file = "/home/wb411133/temp/AFR_friction_2015.tif"
rMisc.clipRaster(inG, selD, out_file)

# %%
sel_G = rasterio.open(out_file)
inD = sel_G.read()
# inD is stored as minutes to travel one meter. Need to convert to second to traverse the entire 1 km cell
mcp = graph.MCP_Geometric(inD[0,:,:])

# %%
in_ports = "/home/public/Data/GLOBAL/INFRA/PORTS/ports_noProv.csv"
out_folder = "/home/wb411133/data/Global/INFRA/PORTS"
ports_file = os.path.join(out_folder, "major_ports.shp")
if not os.path.exists(ports_file):
    inP = pd.read_csv(in_ports)
    inP_geom = [Point(x) for x in zip(inP['Lng'], inP['Lat'])]
    inP = gpd.GeoDataFrame(inP, geometry = inP_geom, crs={'init':'epsg:4326'})
    inP.to_file(ports_file)
else:
    inP = gpd.read_file(ports_file)

# %%
importlib.reload(ma)
ma.generate_market_sheds?

# %%
importlib.reload(ma)
inG = rasterio.open("/home/wb411133/temp/AFR_friction_2015.tif")
out_file = "/home/wb411133/temp/port_sheds_AFR.tif"
ma.generate_market_sheds(inG, inP, out_file)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-00a3e0e84404> in <module>
#       2 inG = rasterio.open("/home/wb411133/temp/AFR_friction_2015.tif")
#       3 out_file = "/home/wb411133/temp/port_sheds_AFR.tif"
# ----> 4 ma.generate_market_sheds(inG, inP, out_file)
#
# ~/Code/INFRA_SAP/infrasap/market_access.py in generate_market_sheds(inR, inH, out_file, verbose, factor, bandIdx)
#     197         extra_size = np.zeros([(xx.shape[0] - xx.shape[1]), xx.shape[0]]) + max_speed
#     198         new_xx = np.hstack([xx, extra_size])
# --> 199     mcp = graph.MCP_Geometric(new_xx)
#     200
#     201
#
# skimage/graph/_mcp.pyx in skimage.graph._mcp.MCP_Geometric.__init__()
#
# skimage/graph/_mcp.pyx in skimage.graph._mcp.MCP.__init__()
#
# skimage/graph/_mcp.pyx in skimage.graph._mcp._offset_edge_map()
#
# MemoryError:

# %%
ma.generate_feature_vectors?

# %%
inD = inG.read()
# inD is stored as minutes to travel one meter. Need to convert to second to traverse the entire 1 km cell
mcp = graph.MCP_Geometric(inD[0,:,:] * 1000)

# %%
drive_time_thresholds = [1, 5, 10, 15] # days
drive_time_thresholds = [x * 24 * 60 for x in drive_time_thresholds] #convert days to minutes
drive_vectors = ma.generate_feature_vectors(inR, mcp, inD, drive_time_thresholds)
drive_vectors.to_file(os.path.join(tutorial_folder, "drive_vectors.shp"))

# %% [markdown]
# # Calculate OD matrix from origins and destinations

# %%
travel_surface_layer = "/home/wb411133/data/Country/NPL/OD_CALC/ct_monsoon_nozero2_4326_190305.tif"
origins_file = "/home/wb411133/data/Country/NPL/OD_CALC/Admin2_Headquarters_Origins.gpkg"
destinations_file = "/home/wb411133/data/Country/NPL/OD_CALC/Urban_Centers_Combined_4326.shp"

inR = rasterio.open(travel_surface_layer)
mcp = graph.MCP_Geometric(inR.read()[0,:,:])

# %%
origins = gpd.read_file(origins_file)
if origins.crs != inR.crs:
    origins = origins.to_crs(inR.crs)
destinations = gpd.read_file(destinations_file)
if destinations.crs != inR.crs:
    destinations = destinations.to_crs(inR.crs)

# %%
# Creates IDs for origins and destinations for attaching to the original files
dest_coords_full = list([inR.index(x.x, x.y) for x in origins['geometry']])
dest_coords_full = [f"{x[0]}_{x[1]}" for x in dest_coords_full]
origins['ID'] = dest_coords_full

o_coords_full = list([inR.index(x.x, x.y) for x in destinations['geometry']])
o_coords_full = [f"{x[0]}_{x[1]}" for x in o_coords_full]
destinations['ID'] = o_coords_full

# %%
# Identify destination coordinates ion the raster for calculating the OD matrix
#    NOTE - the length of the destinations may not match the length of the 
#           origins file due to coincident points
dest_coords = ma.get_mcp_dests(inR, origins)
dest_coords_id = [f"{x[0]}_{x[1]}" for x in dest_coords]

origin_coords = ma.get_mcp_dests(inR, destinations)
origin_coords_id = [f"{x[0]}_{x[1]}" for x in origin_coords]

results = np.zeros([len(dest_coords), len(origin_coords)])

# %%
print("***Origins")
print(origins.shape[0])
print(len(dest_coords_full))
print(len(dest_coords))
print("***Destinations")
print(destinations.shape[0])
print(len(o_coords_full))
print(len(origin_coords))
# Out:
# ***Origins
# 754
# 754
# 753
# ***Destinations
# 508
# 508
# 501

# %%
# BEN TODO - I flipped the origins and destinations incorrectly.
#   Whichever of the two is smaller, that should be the destinations
for dIdx in range(0, len(dest_coords)):
    tPrint(f"Processing {dIdx} of {len(dest_coords)}")
    costs, traceback = mcp.find_costs([dest_coords[dIdx]])
    oIdx=0
    for o in origin_coords:
        res = costs[o]
        results[dIdx,oIdx] = res
        oIdx += 1
# Out:
# 16:16:49	Processing 0 of 753
# 16:19:36	Processing 1 of 753
# 16:22:27	Processing 2 of 753
# 16:25:16	Processing 3 of 753
# 16:28:04	Processing 4 of 753
# 16:30:42	Processing 5 of 753
# 16:33:19	Processing 6 of 753
# 16:33:21	Processing 7 of 753
# 16:36:17	Processing 8 of 753
# 16:38:57	Processing 9 of 753
# 16:41:42	Processing 10 of 753
# 16:44:21	Processing 11 of 753
# 16:47:13	Processing 12 of 753
# 16:49:59	Processing 13 of 753
# 16:52:55	Processing 14 of 753
# 16:55:47	Processing 15 of 753
# 16:58:22	Processing 16 of 753
# 17:01:09	Processing 17 of 753
# 17:03:50	Processing 18 of 753
# 17:06:28	Processing 19 of 753
# 17:09:17	Processing 20 of 753
# 17:12:05	Processing 21 of 753
# 17:14:45	Processing 22 of 753
# 17:17:33	Processing 23 of 753
# 17:20:18	Processing 24 of 753
# 17:23:06	Processing 25 of 753
# 17:25:57	Processing 26 of 753
# 17:28:53	Processing 27 of 753
# 17:31:34	Processing 28 of 753
# 17:34:30	Processing 29 of 753
# 17:37:15	Processing 30 of 753
# 17:39:54	Processing 31 of 753
# 17:42:42	Processing 32 of 753
# 17:45:23	Processing 33 of 753
# 17:48:10	Processing 34 of 753
# 17:51:03	Processing 35 of 753
# 17:53:55	Processing 36 of 753
# 17:56:37	Processing 37 of 753
# 17:59:23	Processing 38 of 753
# 18:02:04	Processing 39 of 753
# 18:04:56	Processing 40 of 753
# 18:07:42	Processing 41 of 753
# 18:10:39	Processing 42 of 753
# 18:13:21	Processing 43 of 753
# 18:16:02	Processing 44 of 753
# 18:18:52	Processing 45 of 753
# 18:21:35	Processing 46 of 753
# 18:24:15	Processing 47 of 753
# 18:27:00	Processing 48 of 753
# 18:29:56	Processing 49 of 753
# 18:32:31	Processing 50 of 753
# 18:35:15	Processing 51 of 753
# 18:38:04	Processing 52 of 753
# 18:40:44	Processing 53 of 753
# 18:43:34	Processing 54 of 753
# 18:46:16	Processing 55 of 753
# 19:00:22	Processing 60 of 753
# 19:03:14	Processing 61 of 753
# 19:06:11	Processing 62 of 753
# 19:09:11	Processing 63 of 753
# 19:11:58	Processing 64 of 753
# 19:14:39	Processing 65 of 753
# 19:17:31	Processing 66 of 753
# 19:20:26	Processing 67 of 753
# 19:23:04	Processing 68 of 753
# 19:25:45	Processing 69 of 753
# 23:22:08	Processing 154 of 753
# 23:24:50	Processing 155 of 753
# 23:27:43	Processing 156 of 753
# 23:30:59	Processing 157 of 753
# 23:33:45	Processing 158 of 753
# 23:36:26	Processing 159 of 753
# 23:39:10	Processing 160 of 753
# 23:41:51	Processing 161 of 753
# 23:44:33	Processing 162 of 753
# 23:47:12	Processing 163 of 753
# 23:50:04	Processing 164 of 753
# 23:52:54	Processing 165 of 753
# 23:55:53	Processing 166 of 753
# 23:58:50	Processing 167 of 753
# 00:01:36	Processing 168 of 753
# 00:04:16	Processing 169 of 753
# 00:06:58	Processing 170 of 753
# 00:09:41	Processing 171 of 753
# 00:12:23	Processing 172 of 753
# 00:15:17	Processing 173 of 753
# 00:18:16	Processing 174 of 753
# 00:21:06	Processing 175 of 753
# 00:23:52	Processing 176 of 753
# 00:26:34	Processing 177 of 753
# 00:29:15	Processing 178 of 753
# 00:32:10	Processing 179 of 753
# 00:34:54	Processing 180 of 753
# 00:37:35	Processing 181 of 753
# 00:40:19	Processing 182 of 753
# 00:43:01	Processing 183 of 753
# 00:45:51	Processing 184 of 753
# 00:48:31	Processing 185 of 753
# 00:51:15	Processing 186 of 753
# 00:53:54	Processing 187 of 753
# 00:56:32	Processing 188 of 753
# 00:59:09	Processing 189 of 753
# 01:01:54	Processing 190 of 753
# 01:04:32	Processing 191 of 753
# 01:07:11	Processing 192 of 753
# 01:09:54	Processing 193 of 753
# 01:12:32	Processing 194 of 753
# 01:15:22	Processing 195 of 753
# 01:18:20	Processing 196 of 753
# 01:20:56	Processing 197 of 753
# 01:23:52	Processing 198 of 753
# 01:26:28	Processing 199 of 753
# 01:29:09	Processing 200 of 753
# 01:31:58	Processing 201 of 753
# 01:34:40	Processing 202 of 753
# 01:37:31	Processing 203 of 753
# 01:40:16	Processing 204 of 753
# 01:43:07	Processing 205 of 753
# 01:45:50	Processing 206 of 753
# 01:48:31	Processing 207 of 753
# 01:51:12	Processing 208 of 753
# 01:54:01	Processing 209 of 753
# 01:56:43	Processing 210 of 753
# 01:59:31	Processing 211 of 753
# 02:02:18	Processing 212 of 753
# 02:05:05	Processing 213 of 753
# 02:07:58	Processing 214 of 753
# 02:10:51	Processing 215 of 753
# 02:13:48	Processing 216 of 753
# 02:16:46	Processing 217 of 753
# 02:19:26	Processing 218 of 753
# 02:22:23	Processing 219 of 753
# 02:25:21	Processing 220 of 753
# 02:28:16	Processing 221 of 753
# 02:31:14	Processing 222 of 753
# 02:34:10	Processing 223 of 753
# 02:36:48	Processing 224 of 753
# 02:39:34	Processing 225 of 753
# 02:42:16	Processing 226 of 753
# 02:44:54	Processing 227 of 753
# 02:47:35	Processing 228 of 753
# 02:50:21	Processing 229 of 753
# 02:53:16	Processing 230 of 753
# 02:56:02	Processing 231 of 753
# 02:59:00	Processing 232 of 753
# 03:01:53	Processing 233 of 753
# 03:04:37	Processing 234 of 753
# 03:07:31	Processing 235 of 753
# 03:10:29	Processing 236 of 753
# 03:13:09	Processing 237 of 753
# 03:16:09	Processing 238 of 753
# 03:18:50	Processing 239 of 753
# 03:21:33	Processing 240 of 753
# 03:24:29	Processing 241 of 753
# 03:27:25	Processing 242 of 753
# 03:30:07	Processing 243 of 753
# 03:32:44	Processing 244 of 753
# 03:35:29	Processing 245 of 753
# 03:38:11	Processing 246 of 753
# 03:41:10	Processing 247 of 753
# 03:43:56	Processing 248 of 753
# 03:46:54	Processing 249 of 753
# 03:49:47	Processing 250 of 753
# 03:52:44	Processing 251 of 753
# 03:55:21	Processing 252 of 753
# 03:58:08	Processing 253 of 753
# 04:00:49	Processing 254 of 753
# 04:03:31	Processing 255 of 753
# 04:06:26	Processing 256 of 753
# 04:09:09	Processing 257 of 753
# 04:11:47	Processing 258 of 753
# 04:14:34	Processing 259 of 753
# 04:17:30	Processing 260 of 753
# 04:20:27	Processing 261 of 753
# 04:23:04	Processing 262 of 753
# 04:25:42	Processing 263 of 753
# 04:28:39	Processing 264 of 753
# 04:31:27	Processing 265 of 753
# 04:34:22	Processing 266 of 753
# 04:36:58	Processing 267 of 753
# 04:39:47	Processing 268 of 753
# 04:42:46	Processing 269 of 753
# 04:45:24	Processing 270 of 753
# 04:48:06	Processing 271 of 753
# 04:51:04	Processing 272 of 753
# 04:53:50	Processing 273 of 753
# 04:56:47	Processing 274 of 753
# 04:59:32	Processing 275 of 753
# 05:02:11	Processing 276 of 753
# 05:04:53	Processing 277 of 753
# 05:07:39	Processing 278 of 753
# 05:10:17	Processing 279 of 753
# 05:13:00	Processing 280 of 753
# 05:15:55	Processing 281 of 753
# 05:18:37	Processing 282 of 753
# 05:21:33	Processing 283 of 753
# 05:24:17	Processing 284 of 753
# 05:27:10	Processing 285 of 753
# 05:30:08	Processing 286 of 753
# 05:33:00	Processing 287 of 753
# 05:35:53	Processing 288 of 753
# 05:38:50	Processing 289 of 753
# 05:41:40	Processing 290 of 753
# 05:44:21	Processing 291 of 753
# 05:47:06	Processing 292 of 753
# 05:50:04	Processing 293 of 753
# 05:52:44	Processing 294 of 753
# 05:55:22	Processing 295 of 753
# 05:58:17	Processing 296 of 753
# 06:00:53	Processing 297 of 753
# 06:03:33	Processing 298 of 753
# 06:06:22	Processing 299 of 753
# 06:09:10	Processing 300 of 753
# 06:11:51	Processing 301 of 753
# 06:14:28	Processing 302 of 753
# 06:17:25	Processing 303 of 753
# 06:20:05	Processing 304 of 753
# 06:22:46	Processing 305 of 753
# 06:25:33	Processing 306 of 753
# 06:28:29	Processing 307 of 753
# 06:31:16	Processing 308 of 753
# 06:33:54	Processing 309 of 753
# 06:36:36	Processing 310 of 753
# 06:39:15	Processing 311 of 753
# 06:41:57	Processing 312 of 753
# 06:44:37	Processing 313 of 753
# 06:47:35	Processing 314 of 753
# 06:50:18	Processing 315 of 753
# 06:53:15	Processing 316 of 753
# 06:55:55	Processing 317 of 753
# 06:58:33	Processing 318 of 753
# 07:01:11	Processing 319 of 753
# 07:04:07	Processing 320 of 753
# 07:07:05	Processing 321 of 753
# 07:09:39	Processing 322 of 753
# 07:12:31	Processing 323 of 753
# 07:15:27	Processing 324 of 753
# 07:18:09	Processing 325 of 753
# 07:20:48	Processing 326 of 753
# 07:23:45	Processing 327 of 753
# 07:26:19	Processing 328 of 753
# 07:29:14	Processing 329 of 753
# 07:31:59	Processing 330 of 753
# 07:34:37	Processing 331 of 753
# 07:37:13	Processing 332 of 753
# 07:39:59	Processing 333 of 753
# 07:42:48	Processing 334 of 753
# 07:45:31	Processing 335 of 753
# 07:48:18	Processing 336 of 753
# 07:51:15	Processing 337 of 753
# 07:54:06	Processing 338 of 753
# 07:56:47	Processing 339 of 753
# 07:59:28	Processing 340 of 753
# 08:02:18	Processing 341 of 753
# 08:05:00	Processing 342 of 753
# 08:07:44	Processing 343 of 753
# 08:10:37	Processing 344 of 753
# 08:13:18	Processing 345 of 753
# 08:16:03	Processing 346 of 753
# 08:18:40	Processing 347 of 753
# 08:21:18	Processing 348 of 753
# 08:24:11	Processing 349 of 753
# 08:27:00	Processing 350 of 753
# 08:29:50	Processing 351 of 753
# 08:32:39	Processing 352 of 753
# 08:35:28	Processing 353 of 753
# 08:38:05	Processing 354 of 753
# 08:40:54	Processing 355 of 753
# 08:43:35	Processing 356 of 753
# 08:46:31	Processing 357 of 753
# 08:49:22	Processing 358 of 753
# 08:52:19	Processing 359 of 753
# 08:55:01	Processing 360 of 753
# 08:57:42	Processing 361 of 753
# 09:00:33	Processing 362 of 753
# 09:03:22	Processing 363 of 753
# 09:06:10	Processing 364 of 753
# 09:09:02	Processing 365 of 753
# 09:11:47	Processing 366 of 753
# 09:14:27	Processing 367 of 753
# 09:17:05	Processing 368 of 753
# 09:20:01	Processing 369 of 753
# 09:22:50	Processing 370 of 753
# 09:25:41	Processing 371 of 753
# 09:28:26	Processing 372 of 753
# 09:31:11	Processing 373 of 753
# 09:33:53	Processing 374 of 753
# 09:36:33	Processing 375 of 753
# 09:39:27	Processing 376 of 753
# 09:42:23	Processing 377 of 753
# 09:45:25	Processing 378 of 753
# 09:48:02	Processing 379 of 753
# 09:50:46	Processing 380 of 753
# 09:53:26	Processing 381 of 753
# 09:56:06	Processing 382 of 753
# 09:59:00	Processing 383 of 753
# 10:01:37	Processing 384 of 753
# 10:04:19	Processing 385 of 753
# 10:07:09	Processing 386 of 753
# 10:09:46	Processing 387 of 753
# 10:12:24	Processing 388 of 753
# 10:15:13	Processing 389 of 753
# 10:17:56	Processing 390 of 753
# 10:20:53	Processing 391 of 753
# 10:23:40	Processing 392 of 753
# 10:26:21	Processing 393 of 753
# 10:29:08	Processing 394 of 753
# 10:31:51	Processing 395 of 753
# 10:34:29	Processing 396 of 753
# 10:37:20	Processing 397 of 753
# 10:40:14	Processing 398 of 753
# 10:43:05	Processing 399 of 753
# 10:45:42	Processing 400 of 753
# 10:48:22	Processing 401 of 753
# 10:51:18	Processing 402 of 753
# 10:54:13	Processing 403 of 753
# 10:57:10	Processing 404 of 753
# 11:00:07	Processing 405 of 753
# 14:56:42	Processing 490 of 753
# 14:59:35	Processing 491 of 753
# 15:02:16	Processing 492 of 753
# 15:05:01	Processing 493 of 753
# 15:07:43	Processing 494 of 753
# 15:10:28	Processing 495 of 753
# 15:13:27	Processing 496 of 753
# 15:16:19	Processing 497 of 753
# 15:19:13	Processing 498 of 753
# 15:21:53	Processing 499 of 753
# 15:24:37	Processing 500 of 753
# 15:27:31	Processing 501 of 753
# 15:30:27	Processing 502 of 753
# 15:33:12	Processing 503 of 753
# 15:35:49	Processing 504 of 753
# 15:38:38	Processing 505 of 753
# 15:41:30	Processing 506 of 753
# 15:44:11	Processing 507 of 753
# 15:46:58	Processing 508 of 753
# 15:49:39	Processing 509 of 753
# 15:52:27	Processing 510 of 753
# 15:55:24	Processing 511 of 753
# 15:58:16	Processing 512 of 753
# 16:01:05	Processing 513 of 753
# 16:04:01	Processing 514 of 753
# 16:06:59	Processing 515 of 753
# 16:09:37	Processing 516 of 753
# 16:12:30	Processing 517 of 753
# 16:15:20	Processing 518 of 753
# 16:18:16	Processing 519 of 753
# 16:20:56	Processing 520 of 753
# 16:23:42	Processing 521 of 753
# 16:26:25	Processing 522 of 753
# 16:29:06	Processing 523 of 753
# 16:32:03	Processing 524 of 753
# 16:34:56	Processing 525 of 753
# 16:37:45	Processing 526 of 753
# 16:40:37	Processing 527 of 753
# 16:43:22	Processing 528 of 753
# 16:46:22	Processing 529 of 753
# 16:49:11	Processing 530 of 753
# 16:52:08	Processing 531 of 753
# 16:54:45	Processing 532 of 753
# 16:57:37	Processing 533 of 753
# 17:00:15	Processing 534 of 753
# 17:03:04	Processing 535 of 753
# 17:05:41	Processing 536 of 753
# 17:08:35	Processing 537 of 753
# 17:11:17	Processing 538 of 753
# 17:14:07	Processing 539 of 753
# 17:16:44	Processing 540 of 753
# 17:19:25	Processing 541 of 753
# 17:22:06	Processing 542 of 753
# 17:24:55	Processing 543 of 753
# 17:27:49	Processing 544 of 753
# 17:30:47	Processing 545 of 753
# 17:33:38	Processing 546 of 753
# 17:36:38	Processing 547 of 753
# 17:39:17	Processing 548 of 753
# 17:42:10	Processing 549 of 753
# 17:45:06	Processing 550 of 753
# 17:47:46	Processing 551 of 753
# 17:50:29	Processing 552 of 753
# 17:53:20	Processing 553 of 753
# 17:56:19	Processing 554 of 753
# 17:59:02	Processing 555 of 753
# 18:01:41	Processing 556 of 753
# 18:04:28	Processing 557 of 753
# 18:07:16	Processing 558 of 753
# 18:10:11	Processing 559 of 753
# 18:13:06	Processing 560 of 753
# 18:15:56	Processing 561 of 753
# 18:18:41	Processing 562 of 753
# 18:21:24	Processing 563 of 753
# 18:24:08	Processing 564 of 753
# 18:27:06	Processing 565 of 753
# 18:29:53	Processing 566 of 753
# 18:32:35	Processing 567 of 753
# 18:35:13	Processing 568 of 753
# 18:37:51	Processing 569 of 753
# 18:40:41	Processing 570 of 753
# 18:43:28	Processing 571 of 753
# 18:46:25	Processing 572 of 753
# 18:49:23	Processing 573 of 753
# 22:50:19	Processing 658 of 753
# 22:53:14	Processing 659 of 753
# 22:56:13	Processing 660 of 753
# 22:58:59	Processing 661 of 753
# 23:01:43	Processing 662 of 753
# 23:04:23	Processing 663 of 753
# 23:07:10	Processing 664 of 753
# 23:10:08	Processing 665 of 753
# 23:12:57	Processing 666 of 753
# 23:15:35	Processing 667 of 753
# 23:18:16	Processing 668 of 753
# 23:21:07	Processing 669 of 753
# 23:23:53	Processing 670 of 753
# 23:26:45	Processing 671 of 753
# 23:28:31	Processing 672 of 753
# 23:31:14	Processing 673 of 753
# 23:33:53	Processing 674 of 753
# 23:36:35	Processing 675 of 753
# 23:39:30	Processing 676 of 753
# 23:42:14	Processing 677 of 753
# 23:44:53	Processing 678 of 753
# 23:47:36	Processing 679 of 753
# 23:50:36	Processing 680 of 753
# 23:53:17	Processing 681 of 753
# 23:56:08	Processing 682 of 753
# 23:58:59	Processing 683 of 753
# 00:01:58	Processing 684 of 753
# 00:04:45	Processing 685 of 753
# 00:07:28	Processing 686 of 753
# 00:10:10	Processing 687 of 753
# 00:12:54	Processing 688 of 753
# 00:15:37	Processing 689 of 753
# 00:18:16	Processing 690 of 753
# 00:21:08	Processing 691 of 753
# 00:23:51	Processing 692 of 753
# 00:26:49	Processing 693 of 753
# 00:29:45	Processing 694 of 753
# 00:32:34	Processing 695 of 753
# 00:35:28	Processing 696 of 753
# 00:38:21	Processing 697 of 753
# 00:41:05	Processing 698 of 753
# 00:44:04	Processing 699 of 753
# 00:46:44	Processing 700 of 753
# 00:49:38	Processing 701 of 753
# 00:52:34	Processing 702 of 753
# 00:55:13	Processing 703 of 753
# 00:57:58	Processing 704 of 753
# 01:00:37	Processing 705 of 753
# 01:03:33	Processing 706 of 753
# 01:06:16	Processing 707 of 753
# 01:09:03	Processing 708 of 753
# 01:11:53	Processing 709 of 753
# 01:14:48	Processing 710 of 753
# 01:17:38	Processing 711 of 753
# 01:20:17	Processing 712 of 753
# 01:23:00	Processing 713 of 753
# 01:25:40	Processing 714 of 753
# 01:28:19	Processing 715 of 753
# 01:31:01	Processing 716 of 753
# 01:33:59	Processing 717 of 753
# 01:36:49	Processing 718 of 753
# 01:39:36	Processing 719 of 753
# 01:42:28	Processing 720 of 753
# 01:45:14	Processing 721 of 753
# 01:48:03	Processing 722 of 753
# 01:50:44	Processing 723 of 753
# 01:53:27	Processing 724 of 753
# 01:56:27	Processing 725 of 753
# 01:59:20	Processing 726 of 753
# 02:02:03	Processing 727 of 753
# 02:04:56	Processing 728 of 753
# 02:07:45	Processing 729 of 753
# 02:10:32	Processing 730 of 753
# 02:13:24	Processing 731 of 753
# 02:16:00	Processing 732 of 753
# 02:18:37	Processing 733 of 753
# 02:21:21	Processing 734 of 753
# 02:24:05	Processing 735 of 753
# 02:26:57	Processing 736 of 753
# 02:29:36	Processing 737 of 753
# 02:32:20	Processing 738 of 753
# 02:35:14	Processing 739 of 753
# 02:37:54	Processing 740 of 753
# 02:40:37	Processing 741 of 753
# 02:43:32	Processing 742 of 753
# 02:46:24	Processing 743 of 753
# 02:49:02	Processing 744 of 753
# 02:51:59	Processing 745 of 753
# 02:54:55	Processing 746 of 753
# 02:57:47	Processing 747 of 753
# 03:00:46	Processing 748 of 753
# 03:03:42	Processing 749 of 753
# 03:06:25	Processing 750 of 753
# 03:09:22	Processing 751 of 753
# 03:12:16	Processing 752 of 753

# %%
all_res = pd.DataFrame(results)
all_res.index = dest_coords_id
all_res.columns = origin_coords_id
all_res.to_csv("/home/wb411133/temp/NPL_OD.csv")
# Out:
# (753, 501)

# %%
origins.to_file("/home/wb411133/temp/NPL_OD_origins.geojson", driver="GeoJSON")
destinations.to_file("/home/wb411133/temp/NPL_OD_destinations.geojson", driver="GeoJSON")

# %% [markdown]
# # Calculate market sheds from travel datasets
# https://scikit-image.org/docs/dev/api/skimage.graph.html#skimage.graph.MCP_Geometric

# %%
import sys, os, importlib
import rasterio

import numpy as np
import pandas as pd
import geopandas as gpd
import osmnx as ox
import GOSTnets as gn
import skimage.graph as graph

from rasterio.mask import mask
from rasterio import features
from shapely.geometry import box, Point, Polygon
from scipy.ndimage import generic_filter
from pandana.loaders import osm

# %%
tutorial_folder ="../tutorial_data"
img = os.path.join(tutorial_folder, "global_friction_surface.tif")
dests = os.path.join(tutorial_folder, "destinations.shp")

img = rasterio.open(img)
inD = gpd.read_file(dests)
data = img.read()[0,:,:]

# %%
mcp = graph.MCP_Geometric(data)
dests_geom = [img.index(x.x, x.y) for x in inD['geometry']]
costs, traceback = mcp.find_costs(dests_geom)

# %%
meta = img.meta.copy()
meta.update(dtype=costs.dtype)

with rasterio.open(os.path.join(tutorial_folder, "market_shed_custom.tif"), 'w', **meta) as outR:
    outR.write_band(1, costs)

# %% [markdown]
# # Debugging below

# %%
import copy
# testing market sheds
dests_geom = [img.index(x.x, x.y) for x in inD['geometry']]
all_c = []
n = inD.shape[0]
idx = 0

# %%
for dest in dests_geom:
    idx += 1
    if dest[0] > 0 and dest[0] < img.shape[0] and dest[1] > 0 and dest[1] < img.shape[1]:
        c1, trace = mcp.find_costs([dest])
        all_c.append(copy.deepcopy(c1))
    else:
        print(f"{idx} of {n} cannot be processed")

# %%
# Iterate through results to generate final marketshed
res = np.zeros(all_c[0].shape)
for idx in range(0, len(all_c)):
    cur_res = all_c[idx]
    if idx == 0:
        min_res = cur_res
    else:
        combo = np.dstack([min_res, cur_res])
        min_res = np.amin(combo, 2)
        cur_val = (min_res == cur_res).astype(np.byte)
        m_idx = np.where(cur_val == 1)
        res[m_idx] = idx

# %%
meta = img.meta.copy()
meta.update(dtype=res.dtype)
with rasterio.open(os.path.join(tutorial_folder, "market_shed_custom.tif"), 'w', **meta) as outR:
    outR.write_band(1, res)

# %%
output.shape

# %%
class MarketShedMCP(graph.MCP_Flexible):
    def _reset(self):
        """reset the id map
        """
        graph.MCP_Flexible._reset(self)
        self._conn = {}
        self._bestconn_v = {}
        self._bestconn = {}
    
    def create_connection(self, id1, id2, pos1, pos2, cost1, cost2):
        # Process data
        hash = min(id1, id2), max(id1, id2)
        val = min(pos1, pos2), max(pos1, pos2)
        cost = min(cost1, cost2)
        # Add to total list 
        self._conn.setdefault(hash, []).append(val)
        # Keep track of connection with lowest cost
        curcost = self._bestconn_v.get(hash, (np.inf,))[0]        
        if cost1 < cost2:
            self._bestconn[val] = (id1,)
        else:
            self._bestconn[val] = (id2,)        
        if cost < curcost:            
            self._bestconn_v[hash] = (cost,) + val
    
mcp_m = MarketShedMCP(data)
costs, traceback = mcp_m.find_costs(dests_geom)

# %%
data.shape[0] * data.shape[1]

# %%
len(mcp_m._bestconn.keys())

# %%
graph.MCP_Flexible.update_node?

# %%
costs, traceback = mcp.find_costs(dests_geom, find_all_ends=True)

# %%
meta = img.meta.copy()
meta.update(dtype=res.dtype, count=5)
with rasterio.open(os.path.join(tutorial_folder, "market_shed.tif"), 'w', **meta) as outR:
    for idx in range(0,5):
        outR.write_band(idx + 1, res[:,:,idx])

# %%
def get_min_axis(x):
    return(np.where(x == x.min()))

res_min = np.apply_along_axis(get_min_axis, 2, res)

# %%
meta = img.meta.copy()
res_min = res_min.astype(meta['dtype'])

# %%
res_min.shape

# %%
meta.update(dtype=res_min.dtype)
with rasterio.open(os.path.join(tutorial_folder, "market_shed_2.tif"), 'w', **meta) as outR:
    outR.write_band(1, res_min[:,:,0,0])

'''
meta.update(dtype=costs.dtype)
with rasterio.open(os.path.join(tutorial_folder, "travel_costs_fa.tif"), 'w', **meta) as outR:
    outR.write_band(1, costs)
    
meta.update(dtype=traceback.dtype)
with rasterio.open(os.path.join(tutorial_folder, "traceback_fa.tif"), 'w', **meta) as outR:
    outR.write_band(1, traceback)
'''

# %%
sys.path.append("../")

import infrasap.market_access as ma

# %%
importlib.reload(ma)
out_file = os.path.join(tutorial_folder, "market_shed_3.tif")
ma.generate_market_sheds(img, mcp, inD, out_file)

# %% [markdown]
# # Calculate area of cells in raster dataset

# %%
global_friction_surface = "/home/public/Data/GLOBAL/INFRA/FRICTION_2015/2015_friction_surface_v1.geotiff"

inG = rasterio.open(global_friction_surface)
inD = inG.read()

# %%
inD.shape

# %%
inG.bounds

# %%
def generate_shape(x, llx, lly, res):
    lly = lly + (x * res)
    ll = (llx, lly)
    ul = (llx, lly + res)
    ur = (llx + res, lly + res)
    lr = (llx + res, lly)
    shape = Polygon([ll, ul, ur, lr, ll])
    return(shape)
    
b = inG.bounds
res = inG.meta['transform'][0]
all_shapes = [generate_shape(x, b[0], b[1], res) for x in range(0, inD.shape[1])]

# %%
res = pd.DataFrame(columns=["idx"])
res['idx'] = list(range(0, inG.shape[0]))
res = gpd.GeoDataFrame(res, geometry=all_shapes, crs = inG.crs)
res['area'] = res['geometry'].apply(lambda x: x.area)

# %%
res.to_file("/home/wb411133/temp/gfs_column1.shp")

# %%
# Convert to UTM to calculate area to metres
'''sys.path.append("../../GOST")

import GOSTRocks.misc as misc
res_sel = res.iloc[1:-1,]
res_utm = misc.project_UTM(res_sel)'''

res_utm = res.to_crs({'init':'epsg:32601'})

# %%
res_utm['area_utm'] = res_utm['geometry'].apply(lambda x: x.area)
res_utm.to_file("/home/wb411133/temp/gfs_column1.shp")

# %%
res_utm.head()

# %%
import numpy as np
import skimage.graph as graph
import copy

# %%
img = np.array([[1,1,2,2,2],[2,1,1,3,3],[3,2,1,2,3],[2,2,2,1,1]])
mcp = graph.MCP_Geometric(img)

# %%
destinations = [[0,0],[3,3]]
costs, traceback = mcp.find_costs(destinations)
print(costs)
print(traceback)

# %%
output

# %%
all_c = []
for dest in destinations:
    costs, traceback = mcp.find_costs([dest])
    all_c.append(copy.deepcopy(costs))

# %%
res = np.dstack(all_c)
res_min = np.amin(res, axis=2)
output = np.zeros([res_min.shape[0], res_min.shape[1]])
for idx in range(0, res.shape[2]):
    cur_data = res[:,:,idx]
    cur_val = (cur_data == res_min).astype(np.byte) * idx
    output = output + cur_val
output = output.astype(np.byte)

# %%
output

# %%
res[:,:,1]

# %%
class MarketShedMCP(graph.MCP_Geometric):
    def _reset(self):
        """reset the id map
        """
        graph.MCP_Flexible._reset(self)
        self._conn = {}
        self._bestconn_v = {}
        self._bestconn = {}
    
    def create_connection(self, id1, id2, pos1, pos2, cost1, cost2):
        # Process data
        hash = min(id1, id2), max(id1, id2)
        print(hash)
        val = min(pos1, pos2), max(pos1, pos2)
        cost = min(cost1, cost2)
        # Add to total list 
        self._conn.setdefault(hash, []).append(val)
        # Keep track of connection with lowest cost
        curcost = self._bestconn_v.get(hash, (np.inf,))[0]        
        if cost1 < cost2:
            self._bestconn[val] = (id1,)
        else:
            self._bestconn[val] = (id2,)        
        if cost < curcost:            
            self._bestconn_v[hash] = (cost,) + val
    
mcp_m = MarketShedMCP(img)
costs, traceback = mcp_m.find_costs(destinations)

# %%
costs

# %%
import numpy as np
from skimage import graph

image = np.array(
    [[1, 1, 2, 2, 2, 2],
     [2, 1, 1, 3, 3, 3],
     [3, 2, 1, 2, 2, 2],
     [3, 2, 2, 1, 1, 1],
     [4, 3, 2, 1, 1, 4],
     [4, 3, 2, 1, 1, 4]]
)
destinations = [[0, 0], [3, 3]]
mcp = graph.MCP_Geometric(image)
costs, traceback = mcp.find_costs(destinations)

# %%
offsets = _mcp.make_offsets(2, True)
offsets.append(np.array([0, 0]))
offsets_arr = np.array(offsets)
indices = np.indices(traceback.shape)
offset_to_neighbor = offsets_arr[traceback]
neighbor_index = indices - offset_to_neighbor.transpose((2, 0, 1))
ids = np.arange(traceback.size).reshape(costs.shape)
neighbor_ids = np.ravel_multi_index(
    tuple(neighbor_index), traceback.shape
)
g = sparse.coo_matrix((
        np.ones(traceback.size),
        (ids.flat, neighbor_ids.flat)),
    )
g.toarray().shape

# %%
sparse.coo_matrix?

# %%
n, components = sparse.csgraph.connected_components(g, directed=False)
basins = components.reshape(costs.shape)

# %%
n, components = sparse.csgraph.connected_components(ids, directed=False)
basins = components.reshape(costs.shape)

# %%
neighbor_ids
