# %% [markdown]
# # Launch INFRA SAP
# The World Bank's Geospatial Operational Support team, in collaboration with the Infrastructure Chief Economist's office have developed a diagnostic toolkit for assessing the state of infrastucture in a country through an assessment of infrastructure, access, connectivity, and commodity flows.
#
# The purpose of this notebook is to launch the data preparation step of the INFRA SAP toolkit. It is principally designed to integrate with the GOST team's high compute cluster, but has been made as flexible as possible to facilitate replication. The steps in data processing require the following input:
# 1. Administrative boundaries of interest (defines total extent of analysis and level of aggregation)
# 2. Country ISO3 code
#
# Based on these basic datasets we will extract the following datasets **these steps are particular to the World Bank's data schema, but can be directly supplied to later functions if necessary**
#
# 1. Open Street Map
# 2. WorldPop 2020 gridded population data
# 3. International airports (from OSM)
# 4. Major ports (from OSM)
# 5. Official Border Crossings (from ???)
#
# With these data either extracted or processed we run the following analyses
#
# 1. Calculate urban and rural following the GURBA process - LINK
# 2. Attempt to identify/name urban areas
# 3. (optional) Re-sample population to 1km
#
# Following these data preparation steps a sanity check should be performed on the extracted data to ensure major POIs are not missed and that all data have been properly extracted

# %%
import sys, os, importlib
import rasterio

import geopandas as gpd
import pandas as pd

sys.path.append("../")

import infrasap.wp_helper as wp
import infrasap.osm_extractor as osm
import infrasap.rai_calculator as rai
import infrasap.gsm_rasterizer as gsm_r
import infrasap.infra_helper as helper

# %%
# Define baseline data
iso3 = "URY"
global_boundaries =  "/home/public/Data/GLOBAL/ADMIN/Admin0_Polys.shp"
global_admin2 = r"/home/public/Data/GLOBAL/ADMIN/Admin2_Polys.shp"
global_osm = "/home/public/Data/GLOBAL/OSM/GLOBAL/planet-latest.osm.pbf"
wp_dataset = "/home/public/Data/GLOBAL/Population/WorldPop_PPP_2020/MOSAIC_ppp_prj_2020/ppp_prj_2020_%s.tif" % iso3
if not os.path.exists(wp_dataset):
    print("Check to make sure population dataset exists")
border_crossings = "/home/public/Data/GLOBAL/INFRA/BORDERS/border_crossings_phv.shp"#J:\Data\GLOBAL\INFRA
global_power_plants = "/home/public/Data/GLOBAL/ENERGY/global_power_plant_database.csv"
grid_lines = "/home/public/Data/GLOBAL/ENERGY/grid.gpkg"

# %%
importlib.reload(helper)

epsg = 32722
base_out = "/home/public/Data/PROJECTS/INFRA_SAP" #r"J:\Data\PROJECTS\INFRA_SAP"
out_folder = os.path.join(base_out, iso3)
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
#define output data
focal_admin2 = os.path.join(out_folder, "admin.shp")
focal_osm = os.path.join(out_folder, "national_complete.osm.pbf")
wp_1km = os.path.join(out_folder, "WP_2020_1km.tif")
urban_extents = os.path.join(out_folder, "urban_extents.shp")
airports = os.path.join(out_folder, "airports.shp")
ports = os.path.join(out_folder, "ports.shp")
borders = os.path.join(out_folder, "borders.shp")
power_plants = os.path.join(out_folder, "power_plants.shp")
transmission = os.path.join(out_folder, "transmission_lines.shp")

global_data = gpd.read_file(global_boundaries)    
# select out admin2 from global boundaries dataset
if not os.path.exists(focal_admin2):
    in_bounds = gpd.read_file(global_admin2)
    out_bounds = in_bounds.loc[in_bounds['ISO3'] == iso3]
    out_bounds = out_bounds.to_crs({'init':'epsg:4326'})
    out_bounds.to_file(focal_admin2)
else:
    out_bounds = gpd.read_file(focal_admin2)
    
# extract national OSM from global OSM PBF
if not os.path.exists(focal_osm):
    ## BEN: Look into using WGET to download from GeoFabrik    
    extractor = osm.osmExtraction(osmosisCmd = "/home/wb411133/Code/Osmosis/bin/osmosis", tempFile = "/home/wb411133/temp/temp_execution.bat")
    print(extractor.extractBoundingBox(global_osm, focal_admin2, focal_osm, execute=False))

# Re-sample WP to 1km
if not os.path.exists(wp_1km):
    inR = rasterio.open(wp_dataset)
    wp.resample_wp(inR, wp_1km, factor=10)
    
# Calculate urban extents from 1km WorldPop
if not os.path.exists(urban_extents):
    urban_shp = wp.calculateUrban(rasterio.open(wp_1km), smooth=False)
    urban_shp.to_file(urban_extents)
    
# Extract airports and ports and rails from OSM
if not os.path.exists(airports):
    pois = osm.load_pois(focal_osm, out_bounds.unary_union)
    for key, value in pois.items():
        value.to_file(os.path.join(out_folder, "%s.shp" % key))

# Extract borders
if not os.path.exists(borders):
    all_borders = gpd.read_file(border_crossings)
    focal_borders = all_borders[all_borders.intersects(out_bounds.unary_union.buffer(0.01))]
    focal_borders.to_file(borders)

# Extract power plants
if not os.path.exists(power_plants):
    pp = helper.extract_power_plants(global_power_plants, out_bounds)
    pp.to_file(power_plants)
    

# Extract transmission lines
if not os.path.exists(transmission):
    lines = helper.extract_transmission_lines(grid_lines, out_bounds)
    lines.to_file(transmission)
    
# Extract and rasterize GSM
gsm_folder = "/home/public/Data/GLOBAL/INFRA/GSMA/"
gsm_shapefiles = []

for root, dirs, files in os.walk(gsm_folder):
    for f in files:
        if (f[-4:] == ".shp") and not ("Inclusions" in f):
            gsm_shapefiles.append(os.path.join(root, f))

gsm_process = gsm_r.gsm_rasterizer(gsm_shapefiles, out_folder)
gsm_process.initial_read_in()
gsm_process.extract_country_vectors(iso3, global_data, out_folder = out_folder)
gsm_process.rasterize_gsm_vectors()

# %%
# Extract and rasterize GSM
gsm_folder = "/home/public/Data/GLOBAL/INFRA/GSMA/"
gsm_shapefiles = []

for root, dirs, files in os.walk(gsm_folder):
    for f in files:
        if (f[-4:] == ".shp") and not ("Inclusions" in f) and not ("National_Rasters" in root):
            gsm_shapefiles.append(os.path.join(root, f))
gsm_shapefiles
# Out:
# ['/home/public/Data/GLOBAL/INFRA/GSMA/2016/Global_3G_201612.shp',
#  '/home/public/Data/GLOBAL/INFRA/GSMA/2016/Global_4G_201612.shp',
#  '/home/public/Data/GLOBAL/INFRA/GSMA/2016/Global_GSM_201612.shp',
#  '/home/public/Data/GLOBAL/INFRA/GSMA/2018/MCE_201812_3G.shp',
#  '/home/public/Data/GLOBAL/INFRA/GSMA/2018/MCE_201812_4G.shp',
#  '/home/public/Data/GLOBAL/INFRA/GSMA/2018/MCE_201812_GSM.shp',
#  '/home/public/Data/GLOBAL/INFRA/GSMA/2017/Data/Global_3G_201712.shp',
#  '/home/public/Data/GLOBAL/INFRA/GSMA/2017/Data/Global_4G_201712.shp',
#  '/home/public/Data/GLOBAL/INFRA/GSMA/2017/Data/Global_GSM_201712.shp']

# %%
importlib.reload(gsm_r)
iso3 = "URY"
gsm_process = gsm_r.gsm_rasterizer(gsm_shapefiles, out_folder)
gsm_process.initial_read_in()
gsm_process.extract_country_vectors(iso3, global_data, out_folder = out_folder)
gsm_process.rasterize_gsm_vectors()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-343-304e07b86eec> in <module>
#       3 gsm_process = gsm_r.gsm_rasterizer(gsm_shapefiles, out_folder)
#       4 gsm_process.initial_read_in()
# ----> 5 gsm_process.extract_country_vectors(iso3, global_data, out_folder = out_folder)
#       6 gsm_process.rasterize_gsm_vectors()
#
# ~/Code/INFRA_SAP/infrasap/gsm_rasterizer.py in extract_country_vectors(self, iso3, global_data, out_folder)
#      46     def extract_country_vectors(self, iso3, global_data, out_folder = ""):
#      47         country_data = global_data[global_data['ISO3'] == iso3]
# ---> 48         if country_data.crs != gsm_process.gsm_data[gsm_process.gsm_data.keys()[0]].crs:
#      49             country_data = country_data.to_crs(gsm_process.gsm_data[gsm_process.gsm_data.keys()[0]].crs)
#      50         if out_folder == "":
#
# NameError: name 'gsm_process' is not defined

# %%
base_data = gsm_process.gsm_data

# %%
importlib.reload(gsm_r)

gsm_process = gsm_r.gsm_rasterizer(gsm_shapefiles, out_folder)
gsm_process.gsm_data = base_data
gsm_process.extract_country_vectors(iso3, global_data, out_folder = out_folder)
gsm_process.rasterize_gsm_vectors()
# Out:
# ../infrasap/gsm_rasterizer.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   select.to_file(out_file)
# TopologyException: Input geom 1 is invalid: Ring Self-intersection at or near point -58.44865462599995 -34.039201843999933 at -58.44865462599995 -34.039201843999933

# %%
gsm_process.gsm_data.keys()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-348-dd16326c6c6c> in <module>
# ----> 1 gsm_process.gsm_data.keys()[0]
#
# TypeError: 'dict_keys' object does not support indexing

# %%
gsm_process.gsm_data[]
# Out:
# {'Global_3G_201612':                    SOURCE CNTRY_COV  CNTRY_CODE    COUNTRY  CNTRY_ISO  \
#  0           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  1           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  2           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  3           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  4           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  5           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  6           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  7           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  8           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  9           Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  10          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  11          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  12          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  13          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  14          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  15          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  16          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  17          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  18          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  19          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  20          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  21          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  22          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  23          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  24          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  25          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  26          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  27          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  28          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  29          Legacy_2009Q1  External    207122.0  Sri Lanka        144
#  ...                   ...       ...         ...        ...        ...
#  5668  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5669  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5670  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5671  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5672  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5673  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5674  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5675  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5676  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5677  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5678  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5679  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5680  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5681  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5682  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5683  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5684  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5685  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5686  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5687  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5688  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5689  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5690  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5691  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5692  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5693  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5694  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5695  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5696  Operator Submission  Internal    207122.0  Sri Lanka        144
#  5697  Operator Submission  Internal    207122.0  Sri Lanka        144
#
#       CNTRY_ISO2 CNTRY_ISO3 CNTRY_FIPS  CNTRY_MC  Shape_Leng    Shape_Area  \
#  0            LK        LKA         CE       413    0.018961  2.246902e-05
#  1            LK        LKA         CE       413    0.018960  2.246852e-05
#  2            LK        LKA         CE       413    0.018960  2.246751e-05
#  3            LK        LKA         CE       413    0.014234  1.123368e-05
#  4            LK        LKA         CE       413    0.028439  2.808287e-05
#  5            LK        LKA         CE       413    0.009480  5.616462e-06
#  6            LK        LKA         CE       413    0.018959  2.246540e-05
#  7            LK        LKA         CE       413    0.014233  1.123125e-05
#  8            LK        LKA         CE       413    0.014204  1.123117e-05
#  9            LK        LKA         CE       413    0.009478  5.614309e-06
#  10           LK        LKA         CE       413    0.014231  1.122678e-05
#  11           LK        LKA         CE       413    0.018953  2.245149e-05
#  12           LK        LKA         CE       413    0.018953  2.245021e-05
#  13           LK        LKA         CE       413    0.014198  1.122441e-05
#  14           LK        LKA         CE       413    0.061546  1.290778e-04
#  15           LK        LKA         CE       413    0.023642  2.244732e-05
#  16           LK        LKA         CE       413    0.066330  1.066238e-04
#  17           LK        LKA         CE       413    0.023705  3.367001e-05
#  18           LK        LKA         CE       413    0.014229  1.122325e-05
#  19           LK        LKA         CE       413    0.014229  1.122271e-05
#  20           LK        LKA         CE       413    0.018918  1.683391e-05
#  21           LK        LKA         CE       413    0.023661  3.364036e-05
#  22           LK        LKA         CE       413    0.018943  2.242640e-05
#  23           LK        LKA         CE       413    0.023624  2.242651e-05
#  24           LK        LKA         CE       413    0.023660  3.363915e-05
#  25           LK        LKA         CE       413    0.009471  5.605833e-06
#  26           LK        LKA         CE       413    0.018941  2.242142e-05
#  27           LK        LKA         CE       413    0.014224  1.121062e-05
#  28           LK        LKA         CE       413    0.137301  3.699508e-04
#  29           LK        LKA         CE       413    0.047350  8.968117e-05
#  ...         ...        ...        ...       ...         ...           ...
#  5668         LK        LKA         CE       413    0.009441  5.570797e-06
#  5669         LK        LKA         CE       413    0.028390  2.785402e-05
#  5670         LK        LKA         CE       413    0.009441  5.570756e-06
#  5671         LK        LKA         CE       413    0.029086  2.965125e-05
#  5672         LK        LKA         CE       413    0.009441  5.570680e-06
#  5673         LK        LKA         CE       413    0.009431  1.071854e-06
#  5674         LK        LKA         CE       413    0.015235  6.887406e-06
#  5675         LK        LKA         CE       413    0.009441  5.570640e-06
#  5676         LK        LKA         CE       413    0.000758  2.024433e-08
#  5677         LK        LKA         CE       413    0.009441  5.570604e-06
#  5678         LK        LKA         CE       413    0.018816  1.671181e-05
#  5679         LK        LKA         CE       413    0.000596  1.008514e-08
#  5680         LK        LKA         CE       413    0.014195  1.114105e-05
#  5681         LK        LKA         CE       413    0.009441  5.570526e-06
#  5682         LK        LKA         CE       413    0.009441  5.570485e-06
#  5683         LK        LKA         CE       413    0.009441  5.570448e-06
#  5684         LK        LKA         CE       413    0.026005  2.917954e-05
#  5685         LK        LKA         CE       413    0.009441  5.570450e-06
#  5686         LK        LKA         CE       413    0.009441  5.570409e-06
#  5687         LK        LKA         CE       413    0.015307  1.154168e-05
#  5688         LK        LKA         CE       413    0.023569  2.785228e-05
#  5689         LK        LKA         CE       413    0.009441  5.570331e-06
#  5690         LK        LKA         CE       413    0.009944  4.702777e-06
#  5691         LK        LKA         CE       413    0.023569  2.785163e-05
#  5692         LK        LKA         CE       413    0.009441  5.570295e-06
#  5693         LK        LKA         CE       413    0.009441  5.570252e-06
#  5694         LK        LKA         CE       413    0.009441  5.570252e-06
#  5695         LK        LKA         CE       413    0.009441  5.570179e-06
#  5696         LK        LKA         CE       413    1.327587  1.682283e-02
#  5697         LK        LKA         CE       413    9.446047  2.046262e-01
#
#                                                 geometry
#  0     POLYGON ((79.98124357500006 6.149158176000071,...
#  1     POLYGON ((79.97648971900009 6.160974304000035,...
#  2     POLYGON ((79.94083580200004 6.184605771000065,...
#  3     POLYGON ((79.95034351400005 6.189331937000077,...
#  4     POLYGON ((79.92657423600008 6.212962137000034,...
#  5     POLYGON ((79.92657423600008 6.224776839000072,...
#  6     POLYGON ((79.92182038000004 6.234228409000025,...
#  7     POLYGON ((79.91706652500005 6.302747184000054,...
#  8     POLYGON ((79.91706652500005 6.305109740000034,...
#  9     POLYGON ((79.89092031900003 6.423223710000059,...
#  10    POLYGON ((79.87428182400004 6.505887212000061,...
#  11    POLYGON ((79.85051254600006 6.550756002000071,...
#  12    POLYGON ((79.84338176200004 6.579092107000065,...
#  13    POLYGON ((79.82198941200005 6.60978773100004, ...
#  14    POLYGON ((79.82198941200005 6.614509966000071,...
#  15    POLYGON ((79.81010477300003 6.640481449000049,...
#  16    POLYGON ((79.80772784500004 6.649925285000052,...
#  17    POLYGON ((79.79822013500007 6.657008043000076,...
#  18    POLYGON ((79.79822013500007 6.661729825000066,...
#  19    POLYGON ((79.78633549500006 6.687698813000054,...
#  20    POLYGON ((79.78633549500006 6.687698813000054,...
#  21    POLYGON ((79.76256621800007 7.074706253000045,...
#  22    POLYGON ((79.75781236200004 7.086500257000068,...
#  23    POLYGON ((79.76732007300006 7.081782692000047,...
#  24    POLYGON ((79.76732007300006 7.091217774000029,...
#  25    POLYGON ((79.72453537300004 7.150182648000055,...
#  26    POLYGON ((79.73404308400006 7.187916177000034,...
#  27    POLYGON ((79.73879694000004 7.192632648000028,...
#  28    POLYGON ((79.73404308400006 7.187916177000034,...
#  29    POLYGON ((79.73879694000004 7.206781767000052,...
#  ...                                                 ...
#  5668  POLYGON ((80.38294437400003 9.59095809400003, ...
#  5669  POLYGON ((80.38532130200008 9.59095809400003, ...
#  5670  POLYGON ((80.37819051800005 9.593301790000055,...
#  5671  POLYGON ((80.36868280700008 9.593301790000055,...
#  5672  POLYGON ((80.29024419000007 9.600332780000031,...
#  5673  POLYGON ((80.38056744600004 9.600332780000031,...
#  5674  POLYGON ((80.36868280700008 9.597989133000056,...
#  5675  POLYGON ((80.39007515700007 9.600332780000031,...
#  5676  POLYGON ((80.36184756500006 9.602676411000061,...
#  5677  POLYGON ((80.29737497300005 9.602676411000061,...
#  5678  POLYGON ((80.29024419000007 9.600332780000031,...
#  5679  POLYGON ((80.37343666300006 9.607363624000072,...
#  5680  POLYGON ((80.29737497300005 9.607363624000072,...
#  5681  POLYGON ((80.38769823000007 9.607363624000072,...
#  5682  POLYGON ((80.28311340600004 9.609707206000053,...
#  5683  POLYGON ((80.27360569500007 9.612050773000021,...
#  5684  POLYGON ((80.36630587900004 9.609707206000053,...
#  5685  POLYGON ((80.37581359100005 9.612050772000032,...
#  5686  POLYGON ((80.28311340600004 9.614394322000066,...
#  5687  POLYGON ((80.36155202300006 9.614394322000066,...
#  5688  POLYGON ((80.41622136300003 9.616737856000043,...
#  5689  POLYGON ((80.28311340600004 9.619081374000075,...
#  5690  POLYGON ((80.35679816900006 9.619081374000075,...
#  5691  POLYGON ((80.27360569500007 9.623768360000042,...
#  5692  POLYGON ((80.36630587900004 9.623768360000042,...
#  5693  POLYGON ((80.35917509600006 9.623768360000042,...
#  5694  POLYGON ((80.39958286800004 9.623768360000042,...
#  5695  POLYGON ((80.40195979600009 9.628455281000072,...
#  5696  POLYGON ((80.36392895100005 9.600332780000031,...
#  5697  POLYGON ((80.63014486500003 9.447962160000031,...
#
#  [5698 rows x 12 columns],
#  'Global_4G_201612':                      SOURCE CNTRY_COV  CNTRY_CODE  COUNTRY  CNTRY_ISO  \
#  0       Operator Submission  External    206969.0    Chile        152
#  1       Operator Submission  External    206969.0    Chile        152
#  2       Operator Submission  External    206969.0    Chile        152
#  3       Operator Submission  External    206969.0    Chile        152
#  4       Operator Submission  External    206969.0    Chile        152
#  5       Operator Submission  External    206969.0    Chile        152
#  6       Operator Submission  External    206969.0    Chile        152
#  7       Operator Submission  External    206969.0    Chile        152
#  8       Operator Submission  External    206969.0    Chile        152
#  9       Operator Submission  External    206969.0    Chile        152
#  10      Operator Submission  External    206969.0    Chile        152
#  11      Operator Submission  External    206969.0    Chile        152
#  12      Operator Submission  External    206969.0    Chile        152
#  13      Operator Submission  External    206969.0    Chile        152
#  14      Operator Submission  External    206969.0    Chile        152
#  15      Operator Submission  External    206969.0    Chile        152
#  16      Operator Submission  External    206969.0    Chile        152
#  17      Operator Submission  External    206969.0    Chile        152
#  18      Operator Submission  External    206969.0    Chile        152
#  19      Operator Submission  External    206969.0    Chile        152
#  20      Operator Submission  External    206969.0    Chile        152
#  21      Operator Submission  External    206969.0    Chile        152
#  22      Operator Submission  Internal    206969.0    Chile        152
#  23      Operator Submission  Internal    206969.0    Chile        152
#  24      Operator Submission  Internal    206969.0    Chile        152
#  25      Operator Submission  Internal    206969.0    Chile        152
#  26      Operator Submission  Internal    206969.0    Chile        152
#  27      Operator Submission  Internal    206969.0    Chile        152
#  28      Operator Submission  Internal    206969.0    Chile        152
#  29      Operator Submission  Internal    206969.0    Chile        152
#  ...                     ...       ...         ...      ...        ...
#  458366  Operator Submission  Internal    207099.0   Russia        643
#  458367  Operator Submission  Internal    207099.0   Russia        643
#  458368  Operator Submission  Internal    207099.0   Russia        643
#  458369  Operator Submission  Internal    207099.0   Russia        643
#  458370  Operator Submission  Internal    207099.0   Russia        643
#  458371  Operator Submission  Internal    207099.0   Russia        643
#  458372  Operator Submission  Internal    207099.0   Russia        643
#  458373  Operator Submission  Internal    207099.0   Russia        643
#  458374  Operator Submission  Internal    207099.0   Russia        643
#  458375  Operator Submission  Internal    207099.0   Russia        643
#  458376  Operator Submission  Internal    207099.0   Russia        643
#  458377  Operator Submission  Internal    207099.0   Russia        643
#  458378  Operator Submission  Internal    207099.0   Russia        643
#  458379  Operator Submission  Internal    207099.0   Russia        643
#  458380  Operator Submission  External    206997.0  Finland        246
#  458381  Operator Submission  External    206997.0  Finland        246
#  458382  Operator Submission  External    206997.0  Finland        246
#  458383  Operator Submission  External    206997.0  Finland        246
#  458384  Operator Submission  External    206997.0  Finland        246
#  458385  Operator Submission  External    206997.0  Finland        246
#  458386  Operator Submission  External    206997.0  Finland        246
#  458387  Operator Submission  External    206997.0  Finland        246
#  458388  Operator Submission  External    206997.0  Finland        246
#  458389  Operator Submission  External    206997.0  Finland        246
#  458390  Operator Submission  External    206997.0  Finland        246
#  458391  Operator Submission  External    206997.0  Finland        246
#  458392  Operator Submission  External    206997.0  Finland        246
#  458393  Operator Submission  External    206997.0  Finland        246
#  458394  Operator Submission  External    206997.0  Finland        246
#  458395  Operator Submission  Internal    206997.0  Finland        246
#
#         CNTRY_ISO2 CNTRY_ISO3 CNTRY_FIPS  CNTRY_MC  Shape_Leng    Shape_Area  \
#  0              CL        CHL         CI       730    0.005314  1.191597e-06
#  1              CL        CHL         CI       730    0.003410  4.908184e-07
#  2              CL        CHL         CI       730    0.011704  5.414500e-06
#  3              CL        CHL         CI       730    0.005047  1.074978e-06
#  4              CL        CHL         CI       730    0.003144  4.170129e-07
#  5              CL        CHL         CI       730    0.007595  3.376555e-06
#  6              CL        CHL         CI       730    0.007596  3.377340e-06
#  7              CL        CHL         CI       730    0.099155  2.338161e-04
#  8              CL        CHL         CI       730    0.007596  3.378014e-06
#  9              CL        CHL         CI       730    0.007604  3.387230e-06
#  10             CL        CHL         CI       730    0.007604  3.387681e-06
#  11             CL        CHL         CI       730    0.156890  2.400940e-04
#  12             CL        CHL         CI       730    0.007605  3.387905e-06
#  13             CL        CHL         CI       730    0.007605  3.388016e-06
#  14             CL        CHL         CI       730    0.194332  3.624963e-04
#  15             CL        CHL         CI       730    0.007613  3.397920e-06
#  16             CL        CHL         CI       730    0.273185  8.430531e-04
#  17             CL        CHL         CI       730    0.012369  6.801251e-06
#  18             CL        CHL         CI       730    0.002665  2.883096e-07
#  19             CL        CHL         CI       730    0.004286  7.458860e-07
#  20             CL        CHL         CI       730    0.004826  9.458633e-07
#  21             CL        CHL         CI       730    0.037166  4.657790e-05
#  22             CL        CHL         CI       730    0.007593  3.374758e-06
#  23             CL        CHL         CI       730    0.007594  3.375991e-06
#  24             CL        CHL         CI       730    0.404915  1.091090e-03
#  25             CL        CHL         CI       730    0.007374  3.143078e-06
#  26             CL        CHL         CI       730    0.007603  3.386443e-06
#  27             CL        CHL         CI       730    0.007603  3.386557e-06
#  28             CL        CHL         CI       730    0.007603  3.386668e-06
#  29             CL        CHL         CI       730    0.007603  3.386668e-06
#  ...           ...        ...        ...       ...         ...           ...
#  458366         RU        RUS         RS       250    0.382836  1.680812e-03
#  458367         RU        RUS         RS       250    0.006976  2.640964e-06
#  458368         RU        RUS         RS       250    0.025682  1.584578e-05
#  458369         RU        RUS         RS       250    2.227429  2.242163e-02
#  458370         RU        RUS         RS       250    0.006976  2.640769e-06
#  458371         RU        RUS         RS       250    0.006976  2.640772e-06
#  458372         RU        RUS         RS       250    0.013951  7.920762e-06
#  458373         RU        RUS         RS       250    0.006973  2.637382e-06
#  458374         RU        RUS         RS       250    0.013946  7.912244e-06
#  458375         RU        RUS         RS       250    0.006973  2.637286e-06
#  458376         RU        RUS         RS       250    0.358210  2.440751e-03
#  458377         RU        RUS         RS       250    0.006960  2.621356e-06
#  458378         RU        RUS         RS       250    0.290066  8.396768e-04
#  458379         RU        RUS         RS       250    0.022820  1.799559e-05
#  458380         FI        FIN         FI       244    0.010914  3.343106e-06
#  458381         FI        FIN         FI       244    0.012757  7.722777e-06
#  458382         FI        FIN         FI       244    0.058790  6.949474e-05
#  458383         FI        FIN         FI       244    0.022264  1.544254e-05
#  458384         FI        FIN         FI       244    0.222123  1.304690e-03
#  458385         FI        FIN         FI       244    0.038263  3.858619e-05
#  458386         FI        FIN         FI       244    0.012752  7.712547e-06
#  458387         FI        FIN         FI       244    0.030257  2.698699e-05
#  458388         FI        FIN         FI       244    0.049267  4.622746e-05
#  458389         FI        FIN         FI       244    0.014839  1.345772e-05
#  458390         FI        FIN         FI       244    0.012748  7.702324e-06
#  458391         FI        FIN         FI       244    0.012747  7.699619e-06
#  458392         FI        FIN         FI       244    0.052502  6.929480e-05
#  458393         FI        FIN         FI       244    0.014365  1.154605e-05
#  458394         FI        FIN         FI       244    3.766394  4.840586e-02
#  458395         FI        FIN         FI       244    1.313811  3.434408e-02
#
#                                                   geometry
#  0       POLYGON ((-70.41476695099993 -53.3122357649999...
#  1       POLYGON ((-70.41300585499994 -53.3108156359999...
#  2       POLYGON ((-70.40948366299995 -53.3079752369999...
#  3       POLYGON ((-70.40772256699995 -53.3065549669999...
#  4       POLYGON ((-70.40596147099996 -53.3051346499999...
#  5       POLYGON ((-70.39271682599997 -53.2980323539999...
#  6       POLYGON ((-70.36894754699995 -53.2895080399999...
#  7       POLYGON ((-70.36894754699995 -53.2895080399999...
#  8       POLYGON ((-70.38320911399995 -53.2809820249999...
#  9       POLYGON ((-70.89662551999999 -53.1642892449999...
#  10      POLYGON ((-70.89424859199994 -53.1585887789999...
#  11      POLYGON ((-70.89424859199994 -53.1585887789999...
#  12      POLYGON ((-70.90613322999997 -53.1557382619999...
#  13      POLYGON ((-70.90375630299997 -53.1543129319999...
#  14      POLYGON ((-70.87761009699994 -53.1372052889999...
#  15      POLYGON ((-70.83957925299995 -53.0272690199999...
#  16      POLYGON ((-70.83957925299995 -53.0272690199999...
#  17      POLYGON ((-70.81105611799995 -52.9943764399999...
#  18      POLYGON ((-72.49299490999994 -51.7419992289999...
#  19      POLYGON ((-72.49956229199995 -51.7375836059999...
#  20      POLYGON ((-72.50175141999995 -51.7361116359999...
#  21      POLYGON ((-72.51293642399997 -51.7287510659999...
#  22      POLYGON ((-70.41173224799996 -53.3207555429999...
#  23      POLYGON ((-70.39271682599997 -53.3065549669999...
#  24      POLYGON ((-70.41173224799996 -53.3207555429999...
#  25      POLYGON ((-70.91847742399995 -53.1756879049999...
#  26      POLYGON ((-70.92277172499996 -53.1728385239999...
#  27      POLYGON ((-70.92277172499996 -53.1728385239999...
#  28      POLYGON ((-70.92752558099994 -53.1714137619999...
#  29      POLYGON ((-70.92039479699997 -53.1714137619999...
#  ...                                                   ...
#  458366  POLYGON ((129.5639575030001 62.12531510800005,...
#  458367  POLYGON ((129.7636194390001 62.13087113400007,...
#  458368  POLYGON ((129.777881006 62.12976001000004, 129...
#  458369  POLYGON ((129.7564886550001 62.12864884600003,...
#  458370  POLYGON ((129.7707502220001 62.13309325900008,...
#  458371  POLYGON ((129.7636194390001 62.13309325900008,...
#  458372  POLYGON ((129.8206657060001 62.14086941400006,...
#  458373  POLYGON ((129.8610734790001 62.17306365200005,...
#  458374  POLYGON ((129.8634504060001 62.17306365200005,...
#  458375  POLYGON ((129.8634504060001 62.17306365200005,...
#  458376  POLYGON ((129.8206657060001 62.14086941400006,...
#  458377  POLYGON ((129.9965583630001 62.35558702700007,...
#  458378  POLYGON ((129.970412158 62.35117528800004, 129...
#  458379  POLYGON ((130.0000000000001 62.34896917500004,...
#  458380  POLYGON ((27.26336187700002 70.00070324100005,...
#  458381  POLYGON ((26.77609167800006 70.01695550000005,...
#  458382  POLYGON ((26.89256114000005 70.02264079700007,...
#  458383  POLYGON ((26.91395349100003 70.02264079700007,...
#  458384  POLYGON ((27.96693250600003 70.02832454300005,...
#  458385  POLYGON ((27.28000037200007 70.03319509100004,...
#  458386  POLYGON ((28.03586341200003 70.04455527200008,...
#  458387  POLYGON ((27.39171597900003 70.04942202300003,...
#  458388  POLYGON ((26.94009969600006 70.06563630400007,...
#  458389  POLYGON ((27.94791708400004 70.07049812300005,...
#  458390  POLYGON ((27.95980172200007 70.07211847600007,...
#  458391  POLYGON ((27.95504786700008 70.07940850300008,...
#  458392  POLYGON ((26.97099975800006 70.07859862600003,...
#  458393  POLYGON ((27.01378445800003 70.08507675400006,...
#  458394  POLYGON ((27.26336187700002 70.00070324100005,...
#  458395  POLYGON ((27.93840937200002 70.07621010600008,...
#
#  [458396 rows x 12 columns],
#  'Global_GSM_201612':                     SOURCE CNTRY_COV  CNTRY_CODE COUNTRY  CNTRY_ISO  \
#  0            Legacy_2009Q1  External    207023.0   India          0
#  1            Legacy_2009Q1  External    207023.0   India          0
#  2            Legacy_2009Q1  External    207023.0   India          0
#  3            Legacy_2009Q1  External    207023.0   India          0
#  4            Legacy_2009Q1  External    207023.0   India          0
#  5            Legacy_2009Q1  External    207023.0   India          0
#  6            Legacy_2009Q1  External    207023.0   India          0
#  7            Legacy_2009Q1  External    207023.0   India          0
#  8            Legacy_2009Q1  External    207023.0   India          0
#  9            Legacy_2009Q1  External    207023.0   India          0
#  10           Legacy_2009Q1  External    207023.0   India          0
#  11           Legacy_2009Q1  External    207023.0   India          0
#  12           Legacy_2009Q1  External    207023.0   India          0
#  13           Legacy_2009Q1  External    207023.0   India          0
#  14           Legacy_2009Q1  External    207023.0   India          0
#  15           Legacy_2009Q1  External    207023.0   India          0
#  16           Legacy_2009Q1  External    207023.0   India          0
#  17           Legacy_2009Q1  External    207023.0   India          0
#  18           Legacy_2009Q1  External    207023.0   India          0
#  19           Legacy_2009Q1  External    207071.0   Nepal          0
#  20           Legacy_2009Q1  External    207071.0   Nepal          0
#  21           Legacy_2009Q1  External    207071.0   Nepal          0
#  22           Legacy_2009Q1  External    207071.0   Nepal          0
#  23           Legacy_2009Q1  External    207071.0   Nepal          0
#  24           Legacy_2009Q1  External    207071.0   Nepal          0
#  25           Legacy_2009Q1  External    207071.0   Nepal          0
#  26           Legacy_2009Q1  External    207071.0   Nepal          0
#  27           Legacy_2009Q1  External    207071.0   Nepal          0
#  28           Legacy_2009Q1  External    207071.0   Nepal          0
#  29           Legacy_2009Q1  External    207071.0   Nepal          0
#  ...                    ...       ...         ...     ...        ...
#  17154  Operator Submission  Internal    207071.0   Nepal          0
#  17155  Operator Submission  Internal    207071.0   Nepal          0
#  17156  Operator Submission  Internal    207071.0   Nepal          0
#  17157  Operator Submission  Internal    207071.0   Nepal          0
#  17158  Operator Submission  Internal    207071.0   Nepal          0
#  17159  Operator Submission  Internal    207071.0   Nepal          0
#  17160  Operator Submission  Internal    207071.0   Nepal          0
#  17161  Operator Submission  Internal    207071.0   Nepal          0
#  17162  Operator Submission  Internal    207071.0   Nepal          0
#  17163  Operator Submission  Internal    207071.0   Nepal          0
#  17164  Operator Submission  Internal    207071.0   Nepal          0
#  17165  Operator Submission  Internal    207071.0   Nepal          0
#  17166  Operator Submission  Internal    207071.0   Nepal          0
#  17167  Operator Submission  Internal    207071.0   Nepal          0
#  17168  Operator Submission  Internal    207071.0   Nepal          0
#  17169  Operator Submission  Internal    207071.0   Nepal          0
#  17170  Operator Submission  Internal    207071.0   Nepal          0
#  17171  Operator Submission  Internal    207071.0   Nepal          0
#  17172  Operator Submission  Internal    207071.0   Nepal          0
#  17173  Operator Submission  Internal    207071.0   Nepal          0
#  17174  Operator Submission  Internal    207071.0   Nepal          0
#  17175  Operator Submission  Internal    207071.0   Nepal          0
#  17176  Operator Submission  Internal    207071.0   Nepal          0
#  17177  Operator Submission  Internal    207071.0   Nepal          0
#  17178  Operator Submission  Internal    207071.0   Nepal          0
#  17179  Operator Submission  Internal    207071.0   Nepal          0
#  17180  Operator Submission  Internal    207071.0   Nepal          0
#  17181  Operator Submission  Internal    207071.0   Nepal          0
#  17182  Operator Submission  Internal    207071.0   Nepal          0
#  17183  Operator Submission  Internal    207071.0   Nepal          0
#
#        CNTRY_ISO2 CNTRY_ISO3 CNTRY_FIPS  CNTRY_MC  Shape_Leng    Shape_Area  \
#  0             IN        IND         IN       404    0.002006  1.439360e-07
#  1             IN        IND         IN       404    0.008250  4.048208e-06
#  2             IN        IND         IN       404    0.126400  1.819360e-04
#  3             IN        IND         IN       404    0.013969  8.980862e-06
#  4             IN        IND         IN       404    0.008905  8.727539e-07
#  5             IN        IND         IN       404    0.031249  4.542550e-05
#  6             IN        IND         IN       404    0.031080  4.482454e-05
#  7             IN        IND         IN       404    0.003796  2.432461e-07
#  8             IN        IND         IN       404    0.017465  1.510656e-05
#  9             IN        IND         IN       404    0.008991  5.035329e-06
#  10            IN        IND         IN       404    0.053935  8.556895e-05
#  11            IN        IND         IN       404    0.022213  2.516660e-05
#  12            IN        IND         IN       404    0.006287  1.784311e-06
#  13            IN        IND         IN       404    0.035564  5.903483e-05
#  14            IN        IND         IN       404    0.000414  7.338004e-09
#  15            IN        IND         IN       404    0.151079  2.404137e-04
#  16            IN        IND         IN       404    0.074743  6.966758e-05
#  17            IN        IND         IN       404    0.006268  1.180594e-06
#  18            IN        IND         IN       404    0.622067  2.098190e-03
#  19            NP        NPL         NP       429    0.008068  3.918772e-06
#  20            NP        NPL         NP       429    0.003943  2.027132e-07
#  21            NP        NPL         NP       429    0.010379  4.069052e-06
#  22            NP        NPL         NP       429    0.025118  3.665649e-05
#  23            NP        NPL         NP       429    0.002215  8.670962e-08
#  24            NP        NPL         NP       429    0.008995  4.929206e-06
#  25            NP        NPL         NP       429    0.009829  5.355825e-06
#  26            NP        NPL         NP       429    0.000879  2.863430e-08
#  27            NP        NPL         NP       429    0.004961  8.491276e-07
#  28            NP        NPL         NP       429    0.033045  3.628681e-05
#  29            NP        NPL         NP       429    0.047311  4.705774e-05
#  ...          ...        ...        ...       ...         ...           ...
#  17154         NP        NPL         NP       429    0.008869  4.891181e-06
#  17155         NP        NPL         NP       429    0.008869  4.891083e-06
#  17156         NP        NPL         NP       429    0.008869  4.890879e-06
#  17157         NP        NPL         NP       429    0.008869  4.890777e-06
#  17158         NP        NPL         NP       429    0.008869  4.890779e-06
#  17159         NP        NPL         NP       429    0.170433  4.499800e-04
#  17160         NP        NPL         NP       429    0.021853  1.956271e-05
#  17161         NP        NPL         NP       429    0.008869  4.890575e-06
#  17162         NP        NPL         NP       429    0.008869  4.890472e-06
#  17163         NP        NPL         NP       429    0.030082  3.912379e-05
#  17164         NP        NPL         NP       429    0.720008  4.357225e-03
#  17165         NP        NPL         NP       429    0.008868  4.889355e-06
#  17166         NP        NPL         NP       429    0.008868  4.889253e-06
#  17167         NP        NPL         NP       429    0.013621  9.777897e-06
#  17168         NP        NPL         NP       429    0.013621  9.777689e-06
#  17169         NP        NPL         NP       429    0.008867  4.888844e-06
#  17170         NP        NPL         NP       429    0.718046  3.227235e-03
#  17171         NP        NPL         NP       429    0.012980  9.776169e-06
#  17172         NP        NPL         NP       429    0.008863  4.883044e-06
#  17173         NP        NPL         NP       429    0.017725  1.464934e-05
#  17174         NP        NPL         NP       429    0.013616  9.766089e-06
#  17175         NP        NPL         NP       429    0.017725  1.464934e-05
#  17176         NP        NPL         NP       429    0.008862  4.882332e-06
#  17177         NP        NPL         NP       429    0.008861  4.881314e-06
#  17178         NP        NPL         NP       429    0.320549  9.422553e-04
#  17179         NP        NPL         NP       429    0.008861  4.880601e-06
#  17180         NP        NPL         NP       429    0.008860  4.880494e-06
#  17181         NP        NPL         NP       429    0.008860  4.880294e-06
#  17182         NP        NPL         NP       429    0.012966  9.759873e-06
#  17183         NP        NPL         NP       429    0.008860  4.879681e-06
#
#                                                  geometry
#  0      POLYGON ((87.83736151800008 26.43402007500003,...
#  1      POLYGON ((87.83838226100005 26.43614847000003,...
#  2      POLYGON ((87.82748224600005 26.42763465500008,...
#  3      POLYGON ((86.05667103400003 26.62116808400003,...
#  4      POLYGON ((88.18164448900006 26.69126980400006,...
#  5      POLYGON ((88.18639834400005 26.70613432800008,...
#  6      POLYGON ((88.19115220000003 26.70825767300005,...
#  7      POLYGON ((84.80403008200005 26.95005896800006,...
#  8      POLYGON ((84.79927622800005 26.96912653700008,...
#  9      POLYGON ((84.79927622800005 26.96912653700008,...
#  10     POLYGON ((84.77550695000008 27.01784009500005,...
#  11     POLYGON ((84.81353779500006 27.01784009500005,...
#  12     POLYGON ((84.81353779500006 27.01784009500005,...
#  13     POLYGON ((84.81829165100004 27.01784009500005,...
#  14     POLYGON ((84.67471800000004 27.25000000000006,...
#  15     POLYGON ((83.66310473900006 27.42577608600004,...
#  16     POLYGON ((83.63695853300004 27.43210524600005,...
#  17     POLYGON ((83.62507389400008 27.43421488600006,...
#  18     POLYGON ((83.52286599900003 27.47007258900004,...
#  19     POLYGON ((87.31881969800008 26.36589070500003,...
#  20     POLYGON ((87.31354484600007 26.36802035600005,...
#  21     POLYGON ((87.21661180200005 26.41060514100008,...
#  22     POLYGON ((87.18333481300004 26.41892195700007,...
#  23     POLYGON ((87.45056537800008 26.43614847000003,...
#  24     POLYGON ((87.46143536500006 26.43797946400002,...
#  25     POLYGON ((84.65428363200004 27.07288217500007,...
#  26     POLYGON ((84.65666056000003 27.07711506300006,...
#  27     POLYGON ((84.66141441600007 27.07923144700004,...
#  28     POLYGON ((84.66854519900005 27.09101903800007,...
#  29     POLYGON ((84.67329905500003 27.10674079900008,...
#  ...                                                  ...
#  17154  POLYGON ((81.71877779800008 30.03496831800004,...
#  17155  POLYGON ((81.64746996400004 30.03702605100005,...
#  17156  POLYGON ((81.56427749000005 30.04114138800003,...
#  17157  POLYGON ((81.55239285100004 30.04319899300003,...
#  17158  POLYGON ((81.61894683000008 30.04114138800003,...
#  17159  POLYGON ((81.65460074700007 30.03496831800004,...
#  17160  POLYGON ((81.57616212900007 30.04731407400004,...
#  17161  POLYGON ((81.80672412600006 30.04525655500004,...
#  17162  POLYGON ((81.60706219100007 30.04731407400004,...
#  17163  POLYGON ((81.55714670700007 30.04525655500004,...
#  17164  POLYGON ((81.70927008600006 30.05760102900007,...
#  17165  POLYGON ((81.63320839600004 30.06994396300007,...
#  17166  POLYGON ((81.57853905700006 30.07200096900004,...
#  17167  POLYGON ((81.57140827400008 30.07817173100005,...
#  17168  POLYGON ((81.53575435600004 30.08022856600007,...
#  17169  POLYGON ((81.55001592400004 30.08022856600007,...
#  17170  POLYGON ((81.53100050200004 30.08022856600007,...
#  17171  POLYGON ((81.48583887300003 30.09462521400008,...
#  17172  POLYGON ((81.46444652300005 30.19739741700005,...
#  17173  POLYGON ((81.49296965700006 30.19945176800007,...
#  17174  POLYGON ((81.50960815100007 30.19739741700005,...
#  17175  POLYGON ((81.51673893400005 30.19945176800007,...
#  17176  POLYGON ((81.53575435600004 30.21177697800005,...
#  17177  POLYGON ((81.50485429500003 30.23231556400003,...
#  17178  POLYGON ((81.52386971800007 30.20561456600007,...
#  17179  POLYGON ((81.50010044000004 30.24669002200005,...
#  17180  POLYGON ((81.49534658400006 30.24874334500004,...
#  17181  POLYGON ((81.49296965700006 30.25284986000003,...
#  17182  POLYGON ((81.48821580100008 30.25900931200005,...
#  17183  POLYGON ((81.49059272900007 30.26516837800006,...
#
#  [17184 rows x 12 columns],
#  'MCE_201812_3G':                    SOURCE CNTRY_COV  CNTRY_CODE COUNTRY  CNTRY_ISO CNTRY_ISO2  \
#  0     Operator Submission  Internal    207023.0   India        356         IN
#  1     Operator Submission  Internal    207023.0   India        356         IN
#  2     Operator Submission  Internal    207023.0   India        356         IN
#  3     Operator Submission  Internal    207023.0   India        356         IN
#  4     Operator Submission  Internal    207023.0   India        356         IN
#  5     Operator Submission  Internal    207023.0   India        356         IN
#  6     Operator Submission  Internal    207023.0   India        356         IN
#  7     Operator Submission  Internal    207023.0   India        356         IN
#  8     Operator Submission  Internal    207023.0   India        356         IN
#  9     Operator Submission  Internal    207023.0   India        356         IN
#  10    Operator Submission  Internal    207023.0   India        356         IN
#  11    Operator Submission  Internal    207023.0   India        356         IN
#  12    Operator Submission  Internal    207023.0   India        356         IN
#  13    Operator Submission  Internal    207023.0   India        356         IN
#  14    Operator Submission  Internal    207023.0   India        356         IN
#  15    Operator Submission  Internal    207023.0   India        356         IN
#  16    Operator Submission  Internal    207023.0   India        356         IN
#  17    Operator Submission  Internal    207023.0   India        356         IN
#  18    Operator Submission  Internal    207023.0   India        356         IN
#  19    Operator Submission  Internal    207023.0   India        356         IN
#  20    Operator Submission  Internal    207023.0   India        356         IN
#  21    Operator Submission  Internal    207023.0   India        356         IN
#  22    Operator Submission  Internal    207023.0   India        356         IN
#  23    Operator Submission  Internal    207023.0   India        356         IN
#  24    Operator Submission  Internal    207023.0   India        356         IN
#  25    Operator Submission  Internal    207023.0   India        356         IN
#  26    Operator Submission  Internal    207023.0   India        356         IN
#  27    Operator Submission  Internal    207023.0   India        356         IN
#  28    Operator Submission  Internal    207023.0   India        356         IN
#  29    Operator Submission  Internal    207023.0   India        356         IN
#  ...                   ...       ...         ...     ...        ...        ...
#  2057  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2058  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2059  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2060  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2061  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2062  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2063  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2064  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2065  Operator Submission  External    207071.0   Nepal        524         NP
#  2066  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2067  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2068  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2069  Operator Submission  External    207071.0   Nepal        524         NP
#  2070  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2071  Operator Submission  External    207071.0   Nepal        524         NP
#  2072  Operator Submission  External    207071.0   Nepal        524         NP
#  2073  Operator Submission  External    207071.0   Nepal        524         NP
#  2074  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2075  Operator Submission  External    207071.0   Nepal        524         NP
#  2076  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2077  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2078  Operator Submission  External    207071.0   Nepal        524         NP
#  2079  Operator Submission  External    207071.0   Nepal        524         NP
#  2080  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2081  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2082  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2083  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2084  Operator Submission  Internal    207071.0   Nepal        524         NP
#  2085  Operator Submission  Internal    207023.0   India        356         IN
#  2086  Operator Submission  External    207071.0   Nepal        524         NP
#
#       CNTRY_ISO3 CNTRY_FIPS  CNTRY_MCC  \
#  0           IND         IN        404
#  1           IND         IN        404
#  2           IND         IN        404
#  3           IND         IN        404
#  4           IND         IN        404
#  5           IND         IN        404
#  6           IND         IN        404
#  7           IND         IN        404
#  8           IND         IN        404
#  9           IND         IN        404
#  10          IND         IN        404
#  11          IND         IN        404
#  12          IND         IN        404
#  13          IND         IN        404
#  14          IND         IN        404
#  15          IND         IN        404
#  16          IND         IN        404
#  17          IND         IN        404
#  18          IND         IN        404
#  19          IND         IN        404
#  20          IND         IN        404
#  21          IND         IN        404
#  22          IND         IN        404
#  23          IND         IN        404
#  24          IND         IN        404
#  25          IND         IN        404
#  26          IND         IN        404
#  27          IND         IN        404
#  28          IND         IN        404
#  29          IND         IN        404
#  ...         ...        ...        ...
#  2057        NPL         NP        429
#  2058        NPL         NP        429
#  2059        NPL         NP        429
#  2060        NPL         NP        429
#  2061        NPL         NP        429
#  2062        NPL         NP        429
#  2063        NPL         NP        429
#  2064        NPL         NP        429
#  2065        NPL         NP        429
#  2066        NPL         NP        429
#  2067        NPL         NP        429
#  2068        NPL         NP        429
#  2069        NPL         NP        429
#  2070        NPL         NP        429
#  2071        NPL         NP        429
#  2072        NPL         NP        429
#  2073        NPL         NP        429
#  2074        NPL         NP        429
#  2075        NPL         NP        429
#  2076        NPL         NP        429
#  2077        NPL         NP        429
#  2078        NPL         NP        429
#  2079        NPL         NP        429
#  2080        NPL         NP        429
#  2081        NPL         NP        429
#  2082        NPL         NP        429
#  2083        NPL         NP        429
#  2084        NPL         NP        429
#  2085        IND         IN        404
#  2086        NPL         NP        429
#
#                                                 geometry
#  0     POLYGON ((84.10759023800006 26.35357733932832,...
#  1     POLYGON ((81.26478458700007 26.35357733932832,...
#  2     POLYGON ((80.11672846000005 26.35357733932832,...
#  3     POLYGON ((81.18159211500006 26.35357733932832,...
#  4     (POLYGON ((80.26172105600006 26.35357733932832...
#  5     POLYGON ((80.58022938100004 26.35357733932832,...
#  6     POLYGON ((80.67530649300005 26.35357733932832,...
#  7     POLYGON ((81.89942431000009 26.35357733932832,...
#  8     POLYGON ((80.08107454300006 26.35357733932832,...
# ...
#  794231        246         FI        FIN         FI       244
#  794232        246         FI        FIN         FI       244
#  794233        246         FI        FIN         FI       244
#  794234        246         FI        FIN         FI       244
#  794235        246         FI        FIN         FI       244
#  794236        246         FI        FIN         FI       244
#  794237        246         FI        FIN         FI       244
#  794238        246         FI        FIN         FI       244
#  794239        246         FI        FIN         FI       244
#  794240        246         FI        FIN         FI       244
#
#                                                   geometry
#  0       POLYGON ((-67.79711166799996 -10.0570294179999...
#  1       POLYGON ((-67.79235781199998 -10.0359650879999...
#  2       POLYGON ((-67.83038865599997 -10.0031956279999...
#  3       POLYGON ((-67.77096546099995 -10.0055364129999...
#  4       POLYGON ((-67.77334238899994 -10.0031956279999...
#  5       POLYGON ((-67.77571931699998 -10.0031956279999...
#  6       POLYGON ((-69.93872361599995 -19.8156351629999...
#  7       POLYGON ((-69.96249289399998 -19.8133989609999...
#  8       POLYGON ((-69.96249289399998 -19.8133989609999...
#  9       POLYGON ((-69.95536211099994 -19.7910352159999...
#  10      POLYGON ((-117.120691925 32.49307274800003, -1...
#  11      POLYGON ((-117.077955765 32.54919060700007, -1...
#  12      POLYGON ((-116.937717025 32.55920796500004, -1...
#  13      POLYGON ((-117.077955765 32.54919060700007, -1...
#  14      POLYGON ((-116.9020631069999 32.55920796500004...
#  15      POLYGON ((-116.9187016019999 32.56121130200006...
#  16      POLYGON ((-115.5044295609999 32.66532317600007...
#  17      POLYGON ((-115.378452388 32.67932898900006, -1...
#  18      POLYGON ((-115.5044295609999 32.66532317600007...
#  19      POLYGON ((-115.197805874 32.68533080800006, -1...
#  20      POLYGON ((-110.1024241439999 31.33295397300003...
#  21      POLYGON ((-114.7475846899999 32.47502742300003...
#  22      POLYGON ((-114.75410212 32.47703263800003, -11...
#  23      POLYGON ((-114.793728148 32.48900176800004, -1...
#  24      POLYGON ((-114.79393279 32.48906298800006, -11...
#  25      POLYGON ((-114.800634664 32.49106789000007, -1...
#  26      POLYGON ((-114.80733654 32.49307274800003, -11...
#  27      POLYGON ((-114.813552246 32.50309636300005, -1...
#  28      POLYGON ((-117.118363537 32.49708232800003, -1...
#  29      POLYGON ((-114.807362913 32.51712755000005, -1...
#  ...                                                   ...
#  794211  POLYGON ((133.599980909 62.40187114900004, 133...
#  794212  POLYGON ((133.6071116930001 62.40297228200006,...
#  794213  POLYGON ((133.561950065 62.41067907400003, 133...
#  794214  POLYGON ((131.1089605750001 62.62238646000003,...
#  794215  POLYGON ((131.2729685920001 62.64969980600006,...
#  794216  POLYGON ((131.1850222640001 62.66825851500005,...
#  794217  POLYGON ((131.256330098 62.66716714800003, 131...
#  794218  POLYGON ((131.1517452740001 62.66934984200003,...
#  794219  POLYGON ((131.1517452740001 62.66934984200003,...
#  794220  POLYGON ((131.0233911730001 62.67698800300008,...
#  794221  POLYGON ((131.1707606970001 62.68135178200004,...
#  794222  POLYGON ((131.2396916030001 62.68789624400006,...
#  794223  POLYGON ((131.0471604510001 62.68898684700008,...
#  794224  POLYGON ((131.1683837700001 62.68135178200004,...
#  794225  POLYGON ((27.26336187700002 70.00070324100005,...
#  794226  POLYGON ((26.77609167800006 70.01695550000005,...
#  794227  POLYGON ((26.89256114100004 70.02264079700007,...
#  794228  POLYGON ((26.91395349100003 70.02264079700007,...
#  794229  POLYGON ((27.96693250700002 70.02832454300005,...
#  794230  POLYGON ((27.28000037200007 70.03319509100004,...
#  794231  POLYGON ((28.03586341200003 70.04455527200008,...
#  794232  POLYGON ((27.39171597900003 70.04942202300003,...
#  794233  POLYGON ((26.94009969600006 70.06563630400007,...
#  794234  POLYGON ((27.94791708400004 70.07049812200006,...
#  794235  POLYGON ((27.95980172300006 70.07211847600007,...
#  794236  POLYGON ((27.95504786700008 70.07940850200004,...
#  794237  POLYGON ((26.97099975800006 70.07859862600003,...
#  794238  POLYGON ((27.01378445800003 70.08507675400006,...
#  794239  POLYGON ((27.26336187700002 70.00070324100005,...
#  794240  POLYGON ((27.93840937200002 70.07621010600008,...
#
#  [794241 rows x 10 columns],
#  'Global_GSM_201712':                    SOURCE CNTRY_COV  CNTRY_CODE    COUNTRY  CNTRY_ISO  \
#  0           Legacy_2009Q1      None         0.0       None          0
#  1           Legacy_2009Q1      None         0.0       None          0
#  2           Legacy_2009Q1      None         0.0       None          0
#  3           Legacy_2009Q1      None         0.0       None          0
#  4           Legacy_2009Q1      None         0.0       None          0
#  5           Legacy_2009Q1      None         0.0       None          0
#  6           Legacy_2009Q1      None         0.0       None          0
#  7           Legacy_2009Q1      None         0.0       None          0
#  8           Legacy_2009Q1      None         0.0       None          0
#  9           Legacy_2009Q1      None         0.0       None          0
#  10          Legacy_2009Q1      None         0.0       None          0
#  11          Legacy_2009Q1      None         0.0       None          0
#  12          Legacy_2009Q1      None         0.0       None          0
#  13          Legacy_2009Q1      None         0.0       None          0
#  14          Legacy_2009Q1      None         0.0       None          0
#  15          Legacy_2009Q1      None         0.0       None          0
#  16          Legacy_2009Q1      None         0.0       None          0
#  17          Legacy_2009Q1      None         0.0       None          0
#  18          Legacy_2009Q1      None         0.0       None          0
#  19          Legacy_2009Q1      None         0.0       None          0
#  20          Legacy_2009Q1      None         0.0       None          0
#  21          Legacy_2009Q1      None         0.0       None          0
#  22          Legacy_2009Q1      None         0.0       None          0
#  23          Legacy_2009Q1      None         0.0       None          0
#  24          Legacy_2009Q1      None         0.0       None          0
#  25          Legacy_2009Q1      None         0.0       None          0
#  26          Legacy_2009Q1      None         0.0       None          0
#  27          Legacy_2009Q1      None         0.0       None          0
#  28          Legacy_2009Q1      None         0.0       None          0
#  29          Legacy_2009Q1      None         0.0       None          0
#  ...                   ...       ...         ...        ...        ...
#  996   Operator Submission  Internal    207122.0  Sri Lanka        144
#  997   Operator Submission  Internal    207122.0  Sri Lanka        144
#  998   Operator Submission  Internal    207122.0  Sri Lanka        144
#  999   Operator Submission  Internal    207122.0  Sri Lanka        144
#  1000  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1001  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1002  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1003  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1004  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1005  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1006  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1007  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1008  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1009  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1010  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1011  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1012  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1013  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1014  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1015  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1016  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1017  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1018  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1019  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1020  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1021  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1022  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1023  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1024  Operator Submission  Internal    207122.0  Sri Lanka        144
#  1025  Operator Submission  Internal    207122.0  Sri Lanka        144
#
#       CNTRY_ISO2 CNTRY_ISO3 CNTRY_FIPS  CNTRY_MC  \
#  0          None       None       None         0
#  1          None       None       None         0
#  2          None       None       None         0
#  3          None       None       None         0
#  4          None       None       None         0
#  5          None       None       None         0
#  6          None       None       None         0
#  7          None       None       None         0
#  8          None       None       None         0
#  9          None       None       None         0
#  10         None       None       None         0
#  11         None       None       None         0
#  12         None       None       None         0
#  13         None       None       None         0
#  14         None       None       None         0
#  15         None       None       None         0
#  16         None       None       None         0
#  17         None       None       None         0
#  18         None       None       None         0
#  19         None       None       None         0
#  20         None       None       None         0
#  21         None       None       None         0
#  22         None       None       None         0
#  23         None       None       None         0
#  24         None       None       None         0
#  25         None       None       None         0
#  26         None       None       None         0
#  27         None       None       None         0
#  28         None       None       None         0
#  29         None       None       None         0
#  ...         ...        ...        ...       ...
#  996          LK        LKA         CE       413
#  997          LK        LKA         CE       413
#  998          LK        LKA         CE       413
#  999          LK        LKA         CE       413
#  1000         LK        LKA         CE       413
#  1001         LK        LKA         CE       413
#  1002         LK        LKA         CE       413
#  1003         LK        LKA         CE       413
#  1004         LK        LKA         CE       413
#  1005         LK        LKA         CE       413
#  1006         LK        LKA         CE       413
#  1007         LK        LKA         CE       413
#  1008         LK        LKA         CE       413
#  1009         LK        LKA         CE       413
#  1010         LK        LKA         CE       413
#  1011         LK        LKA         CE       413
#  1012         LK        LKA         CE       413
#  1013         LK        LKA         CE       413
#  1014         LK        LKA         CE       413
#  1015         LK        LKA         CE       413
#  1016         LK        LKA         CE       413
#  1017         LK        LKA         CE       413
#  1018         LK        LKA         CE       413
#  1019         LK        LKA         CE       413
#  1020         LK        LKA         CE       413
#  1021         LK        LKA         CE       413
#  1022         LK        LKA         CE       413
#  1023         LK        LKA         CE       413
#  1024         LK        LKA         CE       413
#  1025         LK        LKA         CE       413
#
#                                                 geometry
#  0     POLYGON ((79.83862790700005 6.74671409900003, ...
#  1     POLYGON ((79.78633549500006 7.128956167000069,...
#  2     POLYGON ((79.78633549500006 7.128956167000069,...
#  3     POLYGON ((79.93608194700005 8.19842645500006, ...
#  4     POLYGON ((79.93845887400005 8.19842645500006, ...
#  5     POLYGON ((79.93608194700005 8.210189461000027,...
#  6     POLYGON ((79.94321273000008 8.233714427000052,...
#  7     POLYGON ((79.92657423500003 8.250181071000043,...
#  8     POLYGON ((79.96222815200008 8.250181071000043,...
#  9     POLYGON ((79.94321273000008 8.233714427000052,...
#  10    POLYGON ((79.99312821400008 8.261942540000064,...
#  11    POLYGON ((79.96222815200008 8.261942540000064,...
#  12    POLYGON ((79.95034351300006 8.266647030000058,...
#  13    POLYGON ((79.99788206900007 8.268999253000061,...
#  14    POLYGON ((79.73166615500008 8.276055840000026,...
#  15    POLYGON ((79.94321273000008 8.276055840000026,...
#  16    POLYGON ((79.80535091700006 8.290168634000054,...
#  17    POLYGON ((79.80535091700006 8.290168634000054,...
#  18    POLYGON ((79.93845887400005 8.308984906000035,...
#  19    POLYGON ((79.76969700000006 8.308984906000035,...
#  20    POLYGON ((79.94321273000008 8.304280922000032,...
#  21    POLYGON ((79.94321273000008 8.316040774000044,...
#  22    POLYGON ((79.99312821400008 8.276055840000026,...
#  23    POLYGON ((79.85288947400005 8.358373318000076,...
#  24    POLYGON ((79.85526640100005 8.35131821300007, ...
#  25    POLYGON ((80.00000000000006 5.919513702170202,...
#  26    POLYGON ((79.77207392800005 8.999840519000031,...
#  27    POLYGON ((79.91706652500005 9.058527371000025,...
#  28    POLYGON ((79.88616646300005 9.084346554000035,...
#  29    POLYGON ((79.88616646300005 9.084346554000035,...
#  ...                                                 ...
#  996   POLYGON ((80.15951316000007 8.678069099000027,...
#  997   POLYGON ((80.09037727400005 9.294590269000025,...
#  998   POLYGON ((80.05267344700007 9.315255680000064,...
#  999   POLYGON ((80.65259250800005 9.438583292000033,...
#  1000  POLYGON ((80.64873582600006 9.440928033000034,...
#  1001  POLYGON ((80.56342980200003 9.508918562000076,...
#  1002  POLYGON ((80.12623617100007 9.534704543000032,...
#  1003  POLYGON ((80.11126600000006 9.546424800000068,...
#  1004  POLYGON ((80.09771303700006 9.560488576000068,...
#  1005  POLYGON ((80.06443604800006 9.569864103000043,...
#  1006  POLYGON ((80.07632068600003 9.565176372000053,...
#  1007  POLYGON ((80.08345147000006 9.560488576000068,...
#  1008  POLYGON ((80.09058225400008 9.560488576000068,...
#  1009  POLYGON ((80.05968219200008 9.572207945000059,...
#  1010  POLYGON ((80.07632068600003 9.572207945000059,...
#  1011  POLYGON ((80.05968219200008 9.576895580000041,...
#  1012  POLYGON ((80.08744096500004 9.576895580000041,...
#  1013  POLYGON ((80.08205005000008 9.583926910000059,...
#  1014  POLYGON ((80.05518179200004 9.584599585000035,...
#  1015  POLYGON ((80.10246689300004 9.595645470000022,...
#  1016  POLYGON ((80.09058225400008 9.600332780000031,...
#  1017  POLYGON ((80.10246689300004 9.595645470000022,...
#  1018  POLYGON ((80.10641985800004 9.600332780000031,...
#  1019  POLYGON ((80.10377087600006 9.602676411000061,...
#  1020  POLYGON ((80.39007515700007 9.63314213700005, ...
#  1021  POLYGON ((80.38294437300004 9.647202315000072,...
#  1022  POLYGON ((80.37581359000006 9.651888909000036,...
#  1023  POLYGON ((80.36155202200007 9.658918680000056,...
#  1024  POLYGON ((80.36612961000003 9.66126190500006, ...
#  1025  POLYGON ((80.50857375775161 5.919513702170202,...
#
#  [1026 rows x 10 columns]}

# %% [markdown]
# # Calculate RAI

# %%
importlib.reload(rai)
rai_roadnetwork = rai.extract_rai_network(focal_osm, epsg=epsg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-238-8acb1f774954> in <module>
#       1 importlib.reload(rai)
#       2 rai_roadnetwork = rai.extract_rai_network(focal_osm, epsg=epsg)
# ----> 3 rai = rai.calculate_rai(out_bounds, "GID_2", rasterio.open(wp_dataset), rai_roadnetwork)
#
# ~/Code/INFRA_SAP/infrasap/rai_calculator.py in calculate_rai(out_bounds, out_bounds_id, wp_data, roadsGPD_rai)
#      60     all_res = {}
#      61     for road_count in [1,2,3,4]:
# ---> 62         rai_pop = os.path.join(out_folder, "WP_RAI_%s.tif" % road_count)
#      63         # Generate pop map within RAI pop
#      64         if not os.path.exists(rai_pop):
#
# NameError: name 'out_folder' is not defined

# %%
importlib.reload(rai)
rai = rai.calculate_rai(out_bounds, "GID_2", rasterio.open(wp_dataset), rai_roadnetwork, out_folder)

# %%
rai.to_csv(os.path.join(out_folder, "RAI_population.csv"))

# %% [markdown]
# # Debugging below

# %%
class InfraExtractor(osmium.SimpleHandler):
    """ Extractor for use in osmium SimpleHandler to extract nodes and highways
    """
    def __init__(self, verbose=False):
        ''' Extract nodes representing ports and international airports
        '''
        osmium.SimpleHandler.__init__(self)
        self.verbose = verbose
        self.ports = []
        self.bad_ports = []
        self.airports = []   
        self.bad_airports = []        
        
    def node(self, n):
        if n.tags.get('aeroway') == 'aerodrome':
            wkb = wkbfab.create_point(n)
            shp = wkblib.loads(wkb, hex=True)
            self.airports.append([n.id, shp, shp.x, shp.y, n.tags.get('aerodrome:type'), n.tags.get('name'), n.tags.get('name:en')])
        elif n.tags.get('harbour') == "yes":
            wkb = wkbfab.create_point(n)
            shp = wkblib.loads(wkb, hex=True)
            self.ports.append([n.id, shp, shp.x, shp.y])
    
    def way(self, n):
        if n.tags.get('aeroway') == 'aerodrome':
            try:
                wkb = wkbfab.create_multipolygon(n)
            except:
                wkb = wkbfab.create_linestring(n)
            shp = wkblib.loads(wkb, hex=True)
            self.airports.append([n.id, shp, shp.centroid.x, shp.centroid.y, n.tags.get('aerodrome:type'), n.tags.get('name'), n.tags.get('name:en')])
            #except:
            #    self.bad_airports.append([n.id, n.tags.get('aerodrome:type'), n.tags.get('name'), n.tags.get('name:en')])
        elif n.tags.get('harbour') == "yes":
            try:
                wkb = wkbfab.create_multipolygon(n)
                shp = wkblib.loads(wkb, hex=True)
                self.ports.append([n.id, shp, shp.centroid.x, shp.centroid.y])
            except:
                self.bad_ports.append([n.id])

# %%
import osmium
import shapely.wkb as wkblib
wkbfab = osmium.geom.WKBFactory()

importlib.reload(osm)

temp_osm = "/home/public/Data/PROJECTS/INFRA_SAP/URY/test.osm.pbf"
osm_data = osm.load_pois(focal_osm, out_bounds.unary_union)  
#for key, value in osm_data.items():
#    value.to_file(os.path.join(out_folder, "%s.shp" % key))

# %%
osm_data['highways'].to_file(os.path.join(out_folder, "highways.shp"))

# %%
res = pd.DataFrame(h.airports, columns=['OSM_ID', "geometry", "lon", "lat", "type", "name", "name_en"])

# %%
stations = pd.DataFrame(h.rail_stations, columns=['ID','x','y','name'])
stations.to_csv("/home/wb411133/temp/stations.csv")

# %%
h.bridges
# Out:
# []

# %%
import json
#Process submarine cables
submarine_cable_file = "/home/public/Data/GLOBAL/INFRA/SUBMARINE_CABLES/all_submarine_cables.json"
inS = pd.read_json(submarine_cable_file)

submarine_cable_file_geo = "/home/public/Data/GLOBAL/INFRA/SUBMARINE_CABLES/all_submarine_cables_geo.json"
inS_geo = gpd.read_file(submarine_cable_file_geo)

# %%
inS.head()
# Out:
#    cable_id                               id  \
# 0      1571  acs-alaska-oregon-network-akorn
# 1      1307                    aden-djibouti
# 2      1317                          adria-1
# 3      1691                      aeconnect-1
# 4      1629       africa-coast-to-europe-ace
#
#                                 name
# 0  ACS Alaska-Oregon Network (AKORN)
# 1                      Aden-Djibouti
# 2                            Adria-1
# 3                        AEConnect-1
# 4       Africa Coast to Europe (ACE)

# %%
inS_geo.head()
# Out:
#     color                             slug  \
# 0  4d50a2  acs-alaska-oregon-network-akorn
# 1  09addc                    aden-djibouti
# 2  66b646                          adria-1
# 3  933d97                      aeconnect-1
# 4  8dc740       africa-coast-to-europe-ace
#
#                                             geometry
# 0  (LINESTRING (-151.291670394858 60.689928950949...
# 1  (LINESTRING (43.1479928876509 11.5948813293645...
# 2  (LINESTRING (19.9195913741185 39.6195333476855...
# 3  (LINESTRING (-9.23214578701738 54.207114982820...
# 4  (LINESTRING (6.30006977231538 2.36791255870531...
